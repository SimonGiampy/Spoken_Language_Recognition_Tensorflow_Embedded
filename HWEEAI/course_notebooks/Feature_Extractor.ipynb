# %% [markdown]
# ## Data Preprocessing extractor
# This code is meant to extract MFCC features from audio data.

# %%
import tensorflow as tf
import sys
import numpy as np
import pickle
import shutil
import os
import random

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !wget 'https://storage.googleapis.com/download.tensorflow.org/data/speech_commands_v0.02.tar.gz'
dataset_dir = "/content/speech_commands"
shutil.unpack_archive("speech_commands_v0.02.tar.gz", dataset_dir)

shutil.unpack_archive("/content/drive/MyDrive/HAEEAI-lect5/silence.zip", dataset_dir)

# !cp /content/drive/MyDrive/HAEEAI-lect5/models.py models.py
# !cp /content/drive/MyDrive/HAEEAI-lect5/input_data.py input_data.py

import input_data
import models
# Out:
# --2023-04-28 08:08:43--  https://storage.googleapis.com/download.tensorflow.org/data/speech_commands_v0.02.tar.gz
# Resolving storage.googleapis.com (storage.googleapis.com)... 142.251.16.128, 172.253.62.128, 172.253.115.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|142.251.16.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2428923189 (2.3G) [application/gzip]
# Saving to: ‘speech_commands_v0.02.tar.gz’
#
# speech_commands_v0. 100%[===================>]   2.26G   195MB/s    in 13s
#
# 2023-04-28 08:08:56 (173 MB/s) - ‘speech_commands_v0.02.tar.gz’ saved [2428923189/2428923189]

# %%
## Print some dataset information
total_samples = 0;
n_classes = 0 #How many classes the dataset has (it will be automatically found)
iteration = 0

for word in os.fwalk(dataset_dir):
  if(iteration==0):
    print("Number of classes: " + str(len(word[1])))
    n_classes = str(len(word[1]))
    print("--")
    iteration = iteration+1
  else:
    print("Class '" + os.path.basename(word[0]) + "'" + ": " + str(len(word[2])) + " samples")
    total_samples = total_samples + len(word[2])
print('--')
print("The dataset has " +  str(total_samples) + " samples.")
# Out:
# Number of classes: 37
# --
# Class 'marvin': 2100 samples
# Class 'house': 2113 samples
# Class 'silence': 6115 samples
# Class 'one': 3890 samples
# Class 'bird': 2064 samples
# Class 'happy': 2054 samples
# Class 'up': 3723 samples
# Class 'eight': 3787 samples
# Class 'nine': 3934 samples
# Class 'seven': 3998 samples
# Class 'down': 3917 samples
# Class 'right': 3778 samples
# Class 'four': 3728 samples
# Class '_background_noise_': 7 samples
# Class 'tree': 1759 samples
# Class 'two': 3880 samples
# Class 'zero': 4052 samples
# Class 'dog': 2128 samples
# Class 'bed': 2014 samples
# Class 'forward': 1557 samples
# Class 'five': 4052 samples
# Class 'three': 3727 samples
# Class 'no': 3941 samples
# Class 'visual': 1592 samples
# Class 'cat': 2031 samples
# Class 'wow': 2123 samples
# Class 'on': 3845 samples
# Class 'stop': 3872 samples
# Class 'go': 3880 samples
# Class 'learn': 1575 samples
# Class 'backward': 1664 samples
# Class 'off': 3745 samples
# Class 'left': 3801 samples
# Class 'yes': 4044 samples
# Class 'sheila': 2022 samples
# Class 'six': 3860 samples
# Class 'follow': 1579 samples
# --
# The dataset has 111951 samples.

# %%
# Random seed for reproducibility

seed = 22 #Choose a fixed seed to have reproducible results (22=Gonzales o Chiesa)

random.seed(seed)
os.environ['PYTHONHASHSEED'] = str(seed)
np.random.seed(seed)
tf.random.set_seed(seed)
tf.compat.v1.set_random_seed(seed)

# !pip install split_folders
import splitfolders

shutil.rmtree("/content/speech_commands/_background_noise_")
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting split_folders
#   Downloading split_folders-0.5.1-py3-none-any.whl (8.4 kB)
# Installing collected packages: split_folders
# Successfully installed split_folders-0.5.1

# %%
wanted_words = ['sheila']

# %%
## WARNING: running this cell will merge the dataset folders according to the wanted words.

folders = []
wanted_words.insert(0, "silence")

for x in os.fwalk(dataset_dir):
  folders.append(x[1])

unknown_folders = folders[0]

for word in wanted_words:
  unknown_folders.remove(word)

print("Selected words are: " + str(unknown_folders))

## Now we create a new dataset where there is a folder for each word in wanted_words and a folder that contains all other words, called "Unknown".
import shutil


# Function to create new folder if not exists
def make_new_folder(folder_name, parent_folder):

    # Path
    path = os.path.join(parent_folder, folder_name)

    # Create the folder
    # 'new_folder' in
    # parent_folder
    try:
        # mode of the folder
        mode = 0o777

        # Create folder
        os.mkdir(path, mode)
    except OSError as error:
        print(error)

# folder in which all the content will
# be merged
dest_folder_name = "unknown"

# merge_folder path - current_folder
# + merge_folder
merge_folder_path = os.path.join(dataset_dir, dest_folder_name)

# create merge_folder if not exists
make_new_folder(dest_folder_name, dataset_dir)

print("Selected words will be merged in the folder: " + merge_folder_path)
fileindex = 0;

## Building the unknown folder
for folder in unknown_folders:
  file_names = os.listdir(os.path.join(dataset_dir, folder))
  for file_name in file_names:
    srcpath = os.path.join(os.path.join(dataset_dir, folder), file_name)
    shutil.move(srcpath, os.path.join(merge_folder_path, str(fileindex) + "_" + file_name))
    fileindex = fileindex+1
  shutil.rmtree(os.path.join(dataset_dir, folder))

## remove all duplicate in names
for folder in wanted_words:
  file_names = os.listdir(os.path.join(dataset_dir, folder))
  for file_name in file_names:
    srcname = os.path.join(os.path.join(dataset_dir, folder), file_name)
    destname = os.path.join(os.path.join(dataset_dir, folder), str(fileindex) + "_" + file_name)
    os.rename(srcname, destname)
    fileindex = fileindex+1
# Out:
# Selected words are: ['marvin', 'house', 'one', 'bird', 'happy', 'up', 'eight', 'nine', 'seven', 'down', 'right', 'four', 'tree', 'two', 'zero', 'dog', 'bed', 'forward', 'five', 'three', 'no', 'visual', 'cat', 'wow', 'on', 'stop', 'go', 'learn', 'backward', 'off', 'left', 'yes', 'six', 'follow']
# Selected words will be merged in the folder: /content/speech_commands/unknown

# %%
# This function will print the number of samples for each class in your wanted_words dataset.

wanted_words.insert(1, "unknown")
print('The model will learn to distinguish the following words: ' +  str(wanted_words))
print("--")

def printNumSamples(dataset_path):
  total_meaningful_samples = 0

  for word in wanted_words:
    samples = len(os.listdir(os.path.join(dataset_path, word)))
    print('Number of samples in class ' + '"' + word + '"' + ': ' + str(samples))
    total_meaningful_samples = total_meaningful_samples + samples

printNumSamples(dataset_dir)
# Out:
# The model will learn to distinguish the following words: ['silence', 'unknown', 'sheila']
# --
# Number of samples in class "silence": 6115
# Number of samples in class "unknown": 103807
# Number of samples in class "sheila": 2022

# %% [markdown]
# ## Class Rebalancing

# %%
## Class to rebalance:
rebalance_class = 'unknown'

## Number of samples to have at the end:
to_keep = 2000

# %%
## Execute this cell if you want to rebalance.

to_remove = len(os.listdir(os.path.join(dataset_dir, rebalance_class))) - to_keep

if(to_remove<=0):
  to_remove = 0

print("Removing " + str((to_remove)) + " samples from class " + '"' + rebalance_class + '"' + "...")

samples = os.listdir(os.path.join(dataset_dir, rebalance_class))

samples_to_remove = np.random.choice(range(len(samples)), to_remove, replace=False)

for sample_index in samples_to_remove:
  pathname = os.path.join(os.path.join(dataset_dir, rebalance_class), samples[sample_index])
  os.remove(pathname)

print('New number of samples in class ' + '"' + rebalance_class + '"' + ': ' +
      str(len(os.listdir(os.path.join(dataset_dir, rebalance_class)))))

print('--')
printNumSamples(dataset_dir)
# Out:
# Removing 101807 samples from class "unknown"...
# New number of samples in class "unknown": 2000
# --
# Number of samples in class "silence": 6115
# Number of samples in class "unknown": 2000
# Number of samples in class "sheila": 2022

# %% [markdown]
# ## Training-Testing-Validation splitting

# %%
training_percentage = 0.80
testing_percentage = 0.10
validation_percentage = 0.10

# %%
splitfolders.ratio(dataset_dir, output="/content/input_dataset", seed=seed, ratio=(training_percentage, testing_percentage, validation_percentage))

train_dir = "/content/input_dataset/train"
val_dir = "/content/input_dataset/val"
test_dir = "/content/input_dataset/test"
# Out:
# Copying files: 10137 files [00:09, 1069.15 files/s]

# %%
def getSampleList(directory):
  samplelist = []
  for r, d, file in os.walk(directory):
    for f in file:
      if '.wav' in f:
        samplelist.append(os.path.join(r, f))
  return samplelist
print("Training set:")
printNumSamples(train_dir)
print("---")
print("Validation set:")
printNumSamples(val_dir)
print("---")
print("Testing set:")
printNumSamples(test_dir)
# Out:
# Training set:
# Number of samples in class "silence": 4892
# Number of samples in class "unknown": 1600
# Number of samples in class "sheila": 1617
# ---
# Validation set:
# Number of samples in class "silence": 611
# Number of samples in class "unknown": 200
# Number of samples in class "sheila": 202
# ---
# Testing set:
# Number of samples in class "silence": 612
# Number of samples in class "unknown": 200
# Number of samples in class "sheila": 203

# %%
import shutil
representative_dataset_ratio = 0.01
representative_dataset_temp = "/content/representative_dataset_temp"
splitfolders.ratio(dataset_dir, output=representative_dataset_temp, seed=seed, ratio=(1-representative_dataset_ratio, representative_dataset_ratio))

shutil.rmtree("/content/representative_dataset_temp/train")
shutil.move("/content/representative_dataset_temp/val", "/content/representative_dataset")

representative_dataset_dir = "/content/representative_dataset"
shutil.rmtree(representative_dataset_temp)

representative_list = getSampleList(representative_dataset_dir)

print("The representative dataset is composed by " + str(len(representative_list)) + " samples.")
# Out:
# Copying files: 10137 files [00:02, 4293.79 files/s]
# The representative dataset is composed by 103 samples.

# %% [markdown]
# ## Data Augmentation
#
# This section will add background noise and time-shifting to the training samples. You can choose how many samples to augment.

# %%
#########################################################################
## LIBRARIES IMPORT ##
#########################################################################
# !pip install pydub

import os
import random
import numpy as np
from pydub import AudioSegment
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pydub
#   Downloading pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Installing collected packages: pydub
# Successfully installed pydub-0.25.1

# %%
## These functions performs data augmentation on audio samples, in order to build a more robust dataset that can help train the
## network models. It is divided into three parts: the noise augmentation part, the gain staging part and the time-shifting part.

## -----------
## Pipeline of audio processing: (sample) > |noise fetching| > |time shifting |> |gain staging| > |noise augmentation| > (2 samples)
## ----------

## Noise fetching part: a random noise sample is picked from the "silence" folder.

## Time shifting part: each audio sample fetched is shifted by +/- 300ms at most, in order to have the same word represented in
## different positions inside the 1-second window. This will help the recognizer to discriminate better even on early or later windows.
## The sample in its original position is also preserved and passed further into the pipeline. The sample shifted is padded with 0s.

## Gain staging part: this part performs an amplitude difference measurement between the word sample and the noise sample:
## if the signal to noise ratio is too low, the word audio sample is amplified in order to have a clearer utterance.

## Noise augmentation part: its goal is to add the noise sample to the word samples (both the shifted and the original one).

#########################################################################
## USEFUL FUNCTIONS AND VARIABLES ##
#########################################################################

def fetchSample(samples):

    sample_index = random.randint(0, len(samples) -1 )
    sample = AudioSegment.from_file(samples[sample_index])
    path = samples[sample_index]

    samples.pop(sample_index)

    return sample, path

def timeShift(sample):

    shifted_sample = AudioSegment.silent(1000, 16000)
    shift_entity = random.randint(-200, 200)

    if(shift_entity == 0):
        shift_entity = 100

    if(shift_entity > 0):
        shifted_sample = AudioSegment.silent(shift_entity, 16000)
        shifted_sample = shifted_sample.append(sample[0:(1000-shift_entity)], crossfade=0)

    if(shift_entity < 0):
        shift_entity = 0-shift_entity
        shifted_sample = AudioSegment.silent(shift_entity, 16000)
        shifted_sample = sample[shift_entity:1000].append(shifted_sample, crossfade = 0)

    return shifted_sample

def gainAdjust(sample, noise_sample):

    gain_difference = 9 #dBFS

    sample_loudness = sample.dBFS
    noise_loudness = noise_sample.dBFS

    diff = noise_loudness - sample_loudness

    if(diff<0):
        diff = 0-diff

    if(diff < gain_difference):
        to_increase = gain_difference - diff
        sample = sample.apply_gain(+to_increase)

    return sample

def augmentSample(sample, noise_sample, targetfile):
    augmented_sample = noise_sample.overlay(sample)
    augmented_sample.export(targetfile, format='wav')


def runAugmentation(sample, sample_path, noise_sample, destfolder, overwrite):

  print("Processing " + sample_path)

  augmented_sample_file = os.path.basename(sample_path)

  if(not overwrite):
    augmented_sample_file = "aug_" + os.path.basename(sample_path) #Name of new sample

  input_sample = sample
  augmented_sample = timeShift(input_sample) #Shift in time
  augmented_sample = gainAdjust(augmented_sample, noise_sample) #Gain correction
  augmentSample(augmented_sample, noise_sample, os.path.join(destfolder, augmented_sample_file)) #Overlapping of noise and audio + saving

# %%
noise_path = "/content/speech_commands/silence"

class_to_augment = "unknown"
samples_to_overwrite = 1000 #How many samples replace with their augmented version
samples_to_add = 0 #How many augmented samples save as new samples

# %%
#########################################################################
## RUN DATA AUGMENTATION ##
#########################################################################

folder_to_augment = os.path.join(train_dir, class_to_augment)

noise_samples = getSampleList(noise_path)
input_samples = getSampleList(folder_to_augment)

for i in range(samples_to_overwrite):
  input_sample, sample_path = fetchSample(input_samples) #Randomly pick an input sample
  noise_sample, noise_path = fetchSample(noise_samples) #Randomly pick a noise sample
  runAugmentation(input_sample, sample_path, noise_sample, folder_to_augment, True) #Run augmentation

for i in range(samples_to_add):
  input_sample, sample_path = fetchSample(input_samples) #Randomly pick an input sample
  noise_sample, noise_path = fetchSample(noise_samples) #Randomly pick a noise sample
  runAugmentation(input_sample, sample_path, noise_sample, folder_to_augment, False) #Run augmentation

#########################################################################
# Out:
# Processing /content/input_dataset/train/unknown/36542_9f22307d_nohash_0.wav
# Processing /content/input_dataset/train/unknown/96113_61482e52_nohash_2.wav
# Processing /content/input_dataset/train/unknown/19216_bd8412df_nohash_1.wav
# Processing /content/input_dataset/train/unknown/42143_c50f55b8_nohash_13.wav
# Processing /content/input_dataset/train/unknown/85640_ce0cb033_nohash_2.wav
# Processing /content/input_dataset/train/unknown/37248_73cccfaf_nohash_0.wav
# Processing /content/input_dataset/train/unknown/22201_5de8f2f0_nohash_3.wav
# Processing /content/input_dataset/train/unknown/74412_211b928a_nohash_0.wav
# Processing /content/input_dataset/train/unknown/98047_3f45a0cf_nohash_0.wav
# Processing /content/input_dataset/train/unknown/29407_b69002d4_nohash_2.wav
# Processing /content/input_dataset/train/unknown/99506_b29f8b23_nohash_3.wav
# Processing /content/input_dataset/train/unknown/66123_d5cdb23e_nohash_0.wav
# Processing /content/input_dataset/train/unknown/98829_004ae714_nohash_0.wav
# Processing /content/input_dataset/train/unknown/21868_6727b579_nohash_3.wav
# Processing /content/input_dataset/train/unknown/47129_1a5b9ca4_nohash_0.wav
# Processing /content/input_dataset/train/unknown/4754_6ef407da_nohash_1.wav
# Processing /content/input_dataset/train/unknown/92661_b66f4f93_nohash_0.wav
# Processing /content/input_dataset/train/unknown/103571_a55105d0_nohash_0.wav
# Processing /content/input_dataset/train/unknown/86076_1b18600d_nohash_1.wav
# Processing /content/input_dataset/train/unknown/37805_9a356ab9_nohash_0.wav
# Processing /content/input_dataset/train/unknown/32130_e7ea8b76_nohash_3.wav
# Processing /content/input_dataset/train/unknown/5897_c518d1b1_nohash_1.wav
# Processing /content/input_dataset/train/unknown/72029_9a76f8c3_nohash_4.wav
# Processing /content/input_dataset/train/unknown/14300_0d6d7360_nohash_0.wav
# Processing /content/input_dataset/train/unknown/96903_f953e1af_nohash_0.wav
# Processing /content/input_dataset/train/unknown/34635_7910d292_nohash_0.wav
# Processing /content/input_dataset/train/unknown/42979_bfd26d6b_nohash_1.wav
# Processing /content/input_dataset/train/unknown/32456_eeaf97c3_nohash_3.wav
# Processing /content/input_dataset/train/unknown/51984_dd6c6806_nohash_0.wav
# Processing /content/input_dataset/train/unknown/102673_e49428d9_nohash_0.wav
# Processing /content/input_dataset/train/unknown/11733_21cbe292_nohash_0.wav
# Processing /content/input_dataset/train/unknown/78420_54aecbd5_nohash_1.wav
# Processing /content/input_dataset/train/unknown/36007_69a1a79f_nohash_3.wav
# Processing /content/input_dataset/train/unknown/69022_1a5b9ca4_nohash_0.wav
# Processing /content/input_dataset/train/unknown/74917_07089da9_nohash_0.wav
# Processing /content/input_dataset/train/unknown/55433_e49428d9_nohash_1.wav
# Processing /content/input_dataset/train/unknown/25439_460f2bad_nohash_0.wav
# Processing /content/input_dataset/train/unknown/38600_c5a1e46c_nohash_0.wav
# Processing /content/input_dataset/train/unknown/17302_d78858d9_nohash_0.wav
# Processing /content/input_dataset/train/unknown/96175_78030270_nohash_0.wav
# Processing /content/input_dataset/train/unknown/92861_879a2b38_nohash_3.wav
# Processing /content/input_dataset/train/unknown/68925_fa446c16_nohash_0.wav
# Processing /content/input_dataset/train/unknown/7724_b3849d6e_nohash_0.wav
# Processing /content/input_dataset/train/unknown/97405_7117fb6d_nohash_0.wav
# Processing /content/input_dataset/train/unknown/13646_735845ab_nohash_0.wav
# Processing /content/input_dataset/train/unknown/79802_559bc36a_nohash_3.wav
# Processing /content/input_dataset/train/unknown/63544_bf90a57a_nohash_1.wav
# Processing /content/input_dataset/train/unknown/59284_c7b4049e_nohash_2.wav
# Processing /content/input_dataset/train/unknown/53464_b8874962_nohash_0.wav
# Processing /content/input_dataset/train/unknown/97641_bbf38549_nohash_1.wav
# Processing /content/input_dataset/train/unknown/11764_b1f8326d_nohash_1.wav
# Processing /content/input_dataset/train/unknown/97767_508e30ee_nohash_2.wav
# Processing /content/input_dataset/train/unknown/79638_89947bd7_nohash_0.wav
# Processing /content/input_dataset/train/unknown/31508_520e8c0e_nohash_1.wav
# Processing /content/input_dataset/train/unknown/29496_0cd323ec_nohash_0.wav
# Processing /content/input_dataset/train/unknown/24930_1993db46_nohash_1.wav
# Processing /content/input_dataset/train/unknown/33721_1a892463_nohash_0.wav
# Processing /content/input_dataset/train/unknown/18198_bbb2eb5b_nohash_0.wav
# Processing /content/input_dataset/train/unknown/66322_90e72357_nohash_1.wav
# Processing /content/input_dataset/train/unknown/50287_b1df80c0_nohash_1.wav
# Processing /content/input_dataset/train/unknown/22794_ab00c4b2_nohash_0.wav
# Processing /content/input_dataset/train/unknown/9359_5f9cd2eb_nohash_0.wav
# Processing /content/input_dataset/train/unknown/77254_365908bd_nohash_1.wav
# Processing /content/input_dataset/train/unknown/5097_2796ac50_nohash_0.wav
# Processing /content/input_dataset/train/unknown/74090_7cfb1618_nohash_1.wav
# Processing /content/input_dataset/train/unknown/63907_b4ea0d9a_nohash_4.wav
# Processing /content/input_dataset/train/unknown/40155_b36c27c2_nohash_0.wav
# Processing /content/input_dataset/train/unknown/960_460f2bad_nohash_0.wav
# Processing /content/input_dataset/train/unknown/31001_d0faf7e4_nohash_0.wav
# Processing /content/input_dataset/train/unknown/10776_55d3725a_nohash_0.wav
# Processing /content/input_dataset/train/unknown/35835_56eb74ae_nohash_0.wav
# Processing /content/input_dataset/train/unknown/65502_ace072ba_nohash_3.wav
# Processing /content/input_dataset/train/unknown/39913_0165e0e8_nohash_0.wav
# Processing /content/input_dataset/train/unknown/94887_adec6a94_nohash_1.wav
# Processing /content/input_dataset/train/unknown/87732_15c371c7_nohash_0.wav
# Processing /content/input_dataset/train/unknown/17360_924c1a04_nohash_1.wav
# Processing /content/input_dataset/train/unknown/100472_35d1b6ee_nohash_4.wav
# Processing /content/input_dataset/train/unknown/86396_9fac5701_nohash_4.wav
# Processing /content/input_dataset/train/unknown/47460_c245d3d7_nohash_1.wav
# Processing /content/input_dataset/train/unknown/12087_edc53350_nohash_0.wav
# Processing /content/input_dataset/train/unknown/34934_8012c69d_nohash_1.wav
# Processing /content/input_dataset/train/unknown/100317_85b877b5_nohash_0.wav
# Processing /content/input_dataset/train/unknown/7471_c948d727_nohash_1.wav
# Processing /content/input_dataset/train/unknown/56482_8134f43f_nohash_4.wav
# Processing /content/input_dataset/train/unknown/56618_15574821_nohash_0.wav
# Processing /content/input_dataset/train/unknown/101206_f5733968_nohash_2.wav
# Processing /content/input_dataset/train/unknown/67998_1fe4c891_nohash_0.wav
# Processing /content/input_dataset/train/unknown/63867_f798ac78_nohash_1.wav
# Processing /content/input_dataset/train/unknown/54832_b0c0197e_nohash_0.wav
# Processing /content/input_dataset/train/unknown/49558_d312f481_nohash_1.wav
# Processing /content/input_dataset/train/unknown/48879_db9cfc88_nohash_0.wav
# Processing /content/input_dataset/train/unknown/52508_dce5041a_nohash_1.wav
# Processing /content/input_dataset/train/unknown/75288_d7529c0c_nohash_0.wav
# Processing /content/input_dataset/train/unknown/4237_08ab231c_nohash_4.wav
# Processing /content/input_dataset/train/unknown/58579_c0445658_nohash_1.wav
# Processing /content/input_dataset/train/unknown/4739_b4ea0d9a_nohash_8.wav
# Processing /content/input_dataset/train/unknown/52405_8f3f252c_nohash_2.wav
# Processing /content/input_dataset/train/unknown/4983_51eefcc6_nohash_1.wav
# Processing /content/input_dataset/train/unknown/70151_2c6d3924_nohash_0.wav
# Processing /content/input_dataset/train/unknown/81056_1d1fe0a0_nohash_0.wav
# Processing /content/input_dataset/train/unknown/68256_d8a5ace5_nohash_0.wav
# Processing /content/input_dataset/train/unknown/10751_f5e44d34_nohash_1.wav
# Processing /content/input_dataset/train/unknown/74743_06076b6b_nohash_1.wav
# Processing /content/input_dataset/train/unknown/93605_d85270c1_nohash_0.wav
# Processing /content/input_dataset/train/unknown/46530_cd671b5f_nohash_4.wav
# Processing /content/input_dataset/train/unknown/100773_21e8c417_nohash_1.wav
# Processing /content/input_dataset/train/unknown/87414_fbb2f6cc_nohash_2.wav
# Processing /content/input_dataset/train/unknown/85898_a77fbcfd_nohash_3.wav
# Processing /content/input_dataset/train/unknown/67467_2aca1e72_nohash_1.wav
# Processing /content/input_dataset/train/unknown/98951_4c6167ca_nohash_0.wav
# Processing /content/input_dataset/train/unknown/60809_f47d644e_nohash_0.wav
# Processing /content/input_dataset/train/unknown/26457_0132a06d_nohash_1.wav
# Processing /content/input_dataset/train/unknown/42333_4fd1443e_nohash_3.wav
# Processing /content/input_dataset/train/unknown/48602_af6fbbf5_nohash_1.wav
# Processing /content/input_dataset/train/unknown/28983_5a0bc987_nohash_0.wav
# Processing /content/input_dataset/train/unknown/28609_95ba4996_nohash_0.wav
# Processing /content/input_dataset/train/unknown/99385_82e7204d_nohash_0.wav
# Processing /content/input_dataset/train/unknown/58782_51f4d5b0_nohash_0.wav
# Processing /content/input_dataset/train/unknown/92577_3108acca_nohash_1.wav
# Processing /content/input_dataset/train/unknown/64254_3bb68054_nohash_1.wav
# Processing /content/input_dataset/train/unknown/46276_067f61e2_nohash_3.wav
# Processing /content/input_dataset/train/unknown/79984_e6327279_nohash_0.wav
# Processing /content/input_dataset/train/unknown/46349_b1114e4f_nohash_0.wav
# Processing /content/input_dataset/train/unknown/90407_e269bac0_nohash_0.wav
# Processing /content/input_dataset/train/unknown/33549_050170cb_nohash_4.wav
# Processing /content/input_dataset/train/unknown/85470_8d5e1dc0_nohash_0.wav
# Processing /content/input_dataset/train/unknown/50519_7c75a504_nohash_0.wav
# Processing /content/input_dataset/train/unknown/93290_dea820ce_nohash_3.wav
# Processing /content/input_dataset/train/unknown/57748_8f3f252c_nohash_0.wav
# Processing /content/input_dataset/train/unknown/37314_c2aeb59d_nohash_0.wav
# Processing /content/input_dataset/train/unknown/68724_0819edb0_nohash_1.wav
# Processing /content/input_dataset/train/unknown/29595_ddedba85_nohash_5.wav
# Processing /content/input_dataset/train/unknown/36782_460209ac_nohash_4.wav
# Processing /content/input_dataset/train/unknown/101388_0b7ee1a0_nohash_2.wav
# Processing /content/input_dataset/train/unknown/79573_72e382bd_nohash_1.wav
# Processing /content/input_dataset/train/unknown/30929_b665723d_nohash_1.wav
# Processing /content/input_dataset/train/unknown/91034_728be664_nohash_0.wav
# Processing /content/input_dataset/train/unknown/75706_4c6167ca_nohash_6.wav
# Processing /content/input_dataset/train/unknown/25490_31d68957_nohash_2.wav
# Processing /content/input_dataset/train/unknown/75272_236b6113_nohash_0.wav
# Processing /content/input_dataset/train/unknown/17353_365908bd_nohash_4.wav
# Processing /content/input_dataset/train/unknown/25486_4c6167ca_nohash_1.wav
# Processing /content/input_dataset/train/unknown/29729_a045368c_nohash_3.wav
# Processing /content/input_dataset/train/unknown/57597_c7e02d9c_nohash_0.wav
# Processing /content/input_dataset/train/unknown/66129_96c67073_nohash_1.wav
# Processing /content/input_dataset/train/unknown/25236_6e916de8_nohash_0.wav
# Processing /content/input_dataset/train/unknown/65041_264f471d_nohash_4.wav
# Processing /content/input_dataset/train/unknown/95320_0ba018fc_nohash_3.wav
# Processing /content/input_dataset/train/unknown/10979_6ceeb9aa_nohash_0.wav
# Processing /content/input_dataset/train/unknown/35733_cdee383b_nohash_1.wav
# Processing /content/input_dataset/train/unknown/1859_6565a81d_nohash_0.wav
# Processing /content/input_dataset/train/unknown/69592_1b42b551_nohash_0.wav
# Processing /content/input_dataset/train/unknown/1481_3d9200b9_nohash_0.wav
# Processing /content/input_dataset/train/unknown/51942_cdee383b_nohash_0.wav
# Processing /content/input_dataset/train/unknown/75565_fbb56351_nohash_3.wav
# Processing /content/input_dataset/train/unknown/58855_7e843da8_nohash_1.wav
# Processing /content/input_dataset/train/unknown/64228_0717b9f6_nohash_3.wav
# Processing /content/input_dataset/train/unknown/7075_ad63d93c_nohash_4.wav
# Processing /content/input_dataset/train/unknown/78919_1b4c9b89_nohash_1.wav
# Processing /content/input_dataset/train/unknown/13640_4fd1443e_nohash_3.wav
# Processing /content/input_dataset/train/unknown/3967_31f01a8d_nohash_0.wav
# Processing /content/input_dataset/train/unknown/99326_d1453a87_nohash_1.wav
# Processing /content/input_dataset/train/unknown/103717_a04817c2_nohash_4.wav
# Processing /content/input_dataset/train/unknown/45596_f0659908_nohash_3.wav
# Processing /content/input_dataset/train/unknown/22702_4954abe8_nohash_0.wav
# Processing /content/input_dataset/train/unknown/60425_c948d727_nohash_3.wav
# Processing /content/input_dataset/train/unknown/2972_f035e2ea_nohash_0.wav
# Processing /content/input_dataset/train/unknown/40362_d53e25ba_nohash_1.wav
# Processing /content/input_dataset/train/unknown/52809_b4aa9fef_nohash_0.wav
# Processing /content/input_dataset/train/unknown/30860_3a929277_nohash_2.wav
# Processing /content/input_dataset/train/unknown/60331_8134f43f_nohash_0.wav
# Processing /content/input_dataset/train/unknown/32847_531a5b8a_nohash_0.wav
# Processing /content/input_dataset/train/unknown/5350_1ecfb537_nohash_2.wav
# Processing /content/input_dataset/train/unknown/51679_3aa6f4e2_nohash_0.wav
# Processing /content/input_dataset/train/unknown/20229_c39703ec_nohash_1.wav
# Processing /content/input_dataset/train/unknown/58434_b4ea0d9a_nohash_1.wav
# Processing /content/input_dataset/train/unknown/37024_8d9cc260_nohash_1.wav
# Processing /content/input_dataset/train/unknown/36262_b0ae6326_nohash_0.wav
# Processing /content/input_dataset/train/unknown/81488_1acc97de_nohash_0.wav
# Processing /content/input_dataset/train/unknown/93966_3c1e12cf_nohash_0.wav
# Processing /content/input_dataset/train/unknown/21653_d394ef8e_nohash_0.wav
# Processing /content/input_dataset/train/unknown/14736_87d5e978_nohash_1.wav
# Processing /content/input_dataset/train/unknown/20656_bdd22e4d_nohash_0.wav
# Processing /content/input_dataset/train/unknown/70455_37d38e44_nohash_1.wav
# Processing /content/input_dataset/train/unknown/39067_df6bd83f_nohash_1.wav
# Processing /content/input_dataset/train/unknown/41164_d7559b2d_nohash_0.wav
# Processing /content/input_dataset/train/unknown/8591_b544d4fd_nohash_0.wav
# Processing /content/input_dataset/train/unknown/70972_42398aab_nohash_0.wav
# Processing /content/input_dataset/train/unknown/76364_3ce4910e_nohash_2.wav
# Processing /content/input_dataset/train/unknown/37325_7c1d8533_nohash_2.wav
# Processing /content/input_dataset/train/unknown/47944_99e6cab8_nohash_0.wav
# Processing /content/input_dataset/train/unknown/22576_9aa21fa9_nohash_3.wav
# Processing /content/input_dataset/train/unknown/4364_31db232b_nohash_1.wav
# Processing /content/input_dataset/train/unknown/19005_34263ab3_nohash_0.wav
# Processing /content/input_dataset/train/unknown/486_ff21fb59_nohash_2.wav
# Processing /content/input_dataset/train/unknown/33070_85851131_nohash_0.wav
# Processing /content/input_dataset/train/unknown/5190_9e6bb505_nohash_0.wav
# Processing /content/input_dataset/train/unknown/39982_8134f43f_nohash_0.wav
# Processing /content/input_dataset/train/unknown/40470_b665723d_nohash_0.wav
# Processing /content/input_dataset/train/unknown/56970_a4e8a997_nohash_0.wav
# Processing /content/input_dataset/train/unknown/89564_78102205_nohash_0.wav
# Processing /content/input_dataset/train/unknown/91523_e7d0eb3f_nohash_1.wav
# Processing /content/input_dataset/train/unknown/89233_8aa35b0c_nohash_0.wav
# Processing /content/input_dataset/train/unknown/61407_38d78313_nohash_1.wav
# Processing /content/input_dataset/train/unknown/13011_bde0f20a_nohash_1.wav
# Processing /content/input_dataset/train/unknown/101261_2f666bb2_nohash_1.wav
# Processing /content/input_dataset/train/unknown/80086_7213ed54_nohash_4.wav
# Processing /content/input_dataset/train/unknown/40519_7c75a504_nohash_0.wav
# Processing /content/input_dataset/train/unknown/82634_ee1d8d49_nohash_1.wav
# Processing /content/input_dataset/train/unknown/103454_0b7ee1a0_nohash_2.wav
# Processing /content/input_dataset/train/unknown/84281_5f9cd2eb_nohash_6.wav
# Processing /content/input_dataset/train/unknown/68370_cae62f38_nohash_0.wav
# Processing /content/input_dataset/train/unknown/45598_f192e6b4_nohash_0.wav
# Processing /content/input_dataset/train/unknown/100405_2da58b32_nohash_3.wav
# Processing /content/input_dataset/train/unknown/24823_eda072b5_nohash_0.wav
# Processing /content/input_dataset/train/unknown/22560_0d6d7360_nohash_2.wav
# Processing /content/input_dataset/train/unknown/5018_3c6d55b3_nohash_0.wav
# Processing /content/input_dataset/train/unknown/39098_3bdf05d3_nohash_0.wav
# Processing /content/input_dataset/train/unknown/44837_6c429c7b_nohash_4.wav
# Processing /content/input_dataset/train/unknown/40839_c6ca5d01_nohash_2.wav
# Processing /content/input_dataset/train/unknown/100629_b00dff7e_nohash_0.wav
# Processing /content/input_dataset/train/unknown/4479_1ba20be2_nohash_1.wav
# Processing /content/input_dataset/train/unknown/19683_be7fa0a3_nohash_2.wav
# Processing /content/input_dataset/train/unknown/64698_a4e8a997_nohash_0.wav
# Processing /content/input_dataset/train/unknown/25722_9efe5140_nohash_0.wav
# Processing /content/input_dataset/train/unknown/37989_cce7416f_nohash_9.wav
# Processing /content/input_dataset/train/unknown/75721_520e8c0e_nohash_1.wav
# Processing /content/input_dataset/train/unknown/78844_5236848b_nohash_0.wav
# Processing /content/input_dataset/train/unknown/6912_333d7ddb_nohash_1.wav
# Processing /content/input_dataset/train/unknown/92603_4f256313_nohash_1.wav
# Processing /content/input_dataset/train/unknown/146_d4082f3e_nohash_0.wav
# Processing /content/input_dataset/train/unknown/45429_eaa83485_nohash_4.wav
# Processing /content/input_dataset/train/unknown/5697_e9901cf0_nohash_0.wav
# Processing /content/input_dataset/train/unknown/35535_54ad8f22_nohash_3.wav
# Processing /content/input_dataset/train/unknown/48100_b5aacf2c_nohash_0.wav
# Processing /content/input_dataset/train/unknown/63574_d94eb94f_nohash_0.wav
# Processing /content/input_dataset/train/unknown/40978_837f7378_nohash_0.wav
# Processing /content/input_dataset/train/unknown/24927_3d794813_nohash_3.wav
# Processing /content/input_dataset/train/unknown/41871_67fcdb05_nohash_0.wav
# Processing /content/input_dataset/train/unknown/91450_b0ae6326_nohash_0.wav
# Processing /content/input_dataset/train/unknown/67821_890e4ee2_nohash_1.wav
# Processing /content/input_dataset/train/unknown/46243_b8874962_nohash_1.wav
# Processing /content/input_dataset/train/unknown/52367_c2657ba5_nohash_1.wav
# Processing /content/input_dataset/train/unknown/103509_c7dc7278_nohash_2.wav
# Processing /content/input_dataset/train/unknown/12674_a6285644_nohash_0.wav
# Processing /content/input_dataset/train/unknown/72360_5d4e3bb8_nohash_1.wav
# Processing /content/input_dataset/train/unknown/63475_89f680f3_nohash_1.wav
# Processing /content/input_dataset/train/unknown/6852_042a8dde_nohash_2.wav
# Processing /content/input_dataset/train/unknown/69264_1625acd8_nohash_1.wav
# Processing /content/input_dataset/train/unknown/80795_ee6163d5_nohash_0.wav
# Processing /content/input_dataset/train/unknown/48055_31270cb2_nohash_1.wav
# Processing /content/input_dataset/train/unknown/81704_3589bc72_nohash_5.wav
# Processing /content/input_dataset/train/unknown/96994_a05a90c1_nohash_1.wav
# Processing /content/input_dataset/train/unknown/26161_4c6167ca_nohash_2.wav
# Processing /content/input_dataset/train/unknown/179_d9ae8983_nohash_0.wav
# Processing /content/input_dataset/train/unknown/45443_20fd451f_nohash_2.wav
# Processing /content/input_dataset/train/unknown/22444_bdee441c_nohash_1.wav
# Processing /content/input_dataset/train/unknown/25584_d394ef8e_nohash_0.wav
# Processing /content/input_dataset/train/unknown/47645_b59fe16d_nohash_0.wav
# Processing /content/input_dataset/train/unknown/58042_9cde5de8_nohash_0.wav
# Processing /content/input_dataset/train/unknown/98547_97e0c576_nohash_0.wav
# Processing /content/input_dataset/train/unknown/42636_726382d6_nohash_0.wav
# Processing /content/input_dataset/train/unknown/100880_bc196f81_nohash_0.wav
# Processing /content/input_dataset/train/unknown/70039_b00c4c53_nohash_3.wav
# Processing /content/input_dataset/train/unknown/9033_72320401_nohash_0.wav
# Processing /content/input_dataset/train/unknown/20484_fac7deca_nohash_0.wav
# Processing /content/input_dataset/train/unknown/100179_b6091c84_nohash_1.wav
# Processing /content/input_dataset/train/unknown/56181_e3b64217_nohash_1.wav
# Processing /content/input_dataset/train/unknown/98228_327289eb_nohash_0.wav
# Processing /content/input_dataset/train/unknown/91614_825f450d_nohash_2.wav
# Processing /content/input_dataset/train/unknown/30201_c4e00ee9_nohash_2.wav
# Processing /content/input_dataset/train/unknown/27629_88053e92_nohash_2.wav
# Processing /content/input_dataset/train/unknown/1498_695c2127_nohash_0.wav
# Processing /content/input_dataset/train/unknown/88165_256c0a05_nohash_1.wav
# Processing /content/input_dataset/train/unknown/99492_0585b66d_nohash_0.wav
# Processing /content/input_dataset/train/unknown/5755_a1cff772_nohash_1.wav
# Processing /content/input_dataset/train/unknown/92084_6c0f6493_nohash_3.wav
# Processing /content/input_dataset/train/unknown/97610_e49428d9_nohash_4.wav
# Processing /content/input_dataset/train/unknown/66106_4c6944d6_nohash_5.wav
# Processing /content/input_dataset/train/unknown/79154_5cf1ecce_nohash_0.wav
# Processing /content/input_dataset/train/unknown/99976_c9b5ff26_nohash_3.wav
# Processing /content/input_dataset/train/unknown/26892_dc2222d7_nohash_1.wav
# Processing /content/input_dataset/train/unknown/103728_acfd5b5e_nohash_3.wav
# Processing /content/input_dataset/train/unknown/52771_62ccd358_nohash_1.wav
# Processing /content/input_dataset/train/unknown/80659_7f9eb952_nohash_2.wav
# Processing /content/input_dataset/train/unknown/80429_e1469561_nohash_2.wav
# Processing /content/input_dataset/train/unknown/84131_ddedba85_nohash_3.wav
# Processing /content/input_dataset/train/unknown/59291_70a00e98_nohash_2.wav
# Processing /content/input_dataset/train/unknown/99281_eeaf97c3_nohash_3.wav
# Processing /content/input_dataset/train/unknown/45628_2796ac50_nohash_0.wav
# Processing /content/input_dataset/train/unknown/100974_b4877f8e_nohash_0.wav
# Processing /content/input_dataset/train/unknown/94347_0d85a428_nohash_1.wav
# Processing /content/input_dataset/train/unknown/57469_6c968bd9_nohash_0.wav
# Processing /content/input_dataset/train/unknown/36231_c7dc7278_nohash_3.wav
# Processing /content/input_dataset/train/unknown/42749_c5e3817f_nohash_1.wav
# Processing /content/input_dataset/train/unknown/15730_a04817c2_nohash_4.wav
# Processing /content/input_dataset/train/unknown/39642_d9aa8c90_nohash_0.wav
# Processing /content/input_dataset/train/unknown/79535_0ff728b5_nohash_0.wav
# Processing /content/input_dataset/train/unknown/25223_9735764a_nohash_1.wav
# Processing /content/input_dataset/train/unknown/24082_c7aa72e6_nohash_0.wav
# Processing /content/input_dataset/train/unknown/25466_a331d9cb_nohash_0.wav
# Processing /content/input_dataset/train/unknown/20423_2f0ce4d9_nohash_0.wav
# Processing /content/input_dataset/train/unknown/65215_43f57297_nohash_0.wav
# Processing /content/input_dataset/train/unknown/31772_616420be_nohash_1.wav
# Processing /content/input_dataset/train/unknown/56033_f575faf3_nohash_4.wav
# Processing /content/input_dataset/train/unknown/74843_fd5ccd39_nohash_3.wav
# Processing /content/input_dataset/train/unknown/54191_7c86c03e_nohash_1.wav
# Processing /content/input_dataset/train/unknown/22037_113b3fbc_nohash_1.wav
# Processing /content/input_dataset/train/unknown/66103_da040491_nohash_0.wav
# Processing /content/input_dataset/train/unknown/58574_179a61b7_nohash_3.wav
# Processing /content/input_dataset/train/unknown/48067_5ebc1cda_nohash_3.wav
# Processing /content/input_dataset/train/unknown/79172_d4dddb92_nohash_1.wav
# Processing /content/input_dataset/train/unknown/90522_551e42e8_nohash_0.wav
# Processing /content/input_dataset/train/unknown/83279_b414c653_nohash_3.wav
# Processing /content/input_dataset/train/unknown/95160_c0e0f834_nohash_0.wav
# Processing /content/input_dataset/train/unknown/47141_d486fb84_nohash_0.wav
# Processing /content/input_dataset/train/unknown/13124_459345ea_nohash_2.wav
# Processing /content/input_dataset/train/unknown/14156_6a497f80_nohash_0.wav
# Processing /content/input_dataset/train/unknown/67154_45692b02_nohash_1.wav
# Processing /content/input_dataset/train/unknown/85727_e882abb2_nohash_2.wav
# Processing /content/input_dataset/train/unknown/56949_9a7c1f83_nohash_5.wav
# Processing /content/input_dataset/train/unknown/88583_cc4f9250_nohash_3.wav
# Processing /content/input_dataset/train/unknown/20403_11321027_nohash_1.wav
# Processing /content/input_dataset/train/unknown/85520_cc3b5b62_nohash_2.wav
# Processing /content/input_dataset/train/unknown/58657_d962e5ac_nohash_3.wav
# Processing /content/input_dataset/train/unknown/50340_74b73f88_nohash_0.wav
# Processing /content/input_dataset/train/unknown/91213_64e48f55_nohash_1.wav
# Processing /content/input_dataset/train/unknown/15796_f8f60f59_nohash_1.wav
# Processing /content/input_dataset/train/unknown/32406_070b49af_nohash_0.wav
# Processing /content/input_dataset/train/unknown/33872_c50f55b8_nohash_0.wav
# Processing /content/input_dataset/train/unknown/96121_ce9410da_nohash_0.wav
# Processing /content/input_dataset/train/unknown/10483_283d7a53_nohash_0.wav
# Processing /content/input_dataset/train/unknown/86485_0d82fd99_nohash_3.wav
# Processing /content/input_dataset/train/unknown/1279_b575b5fb_nohash_0.wav
# Processing /content/input_dataset/train/unknown/77375_5e1b34a6_nohash_0.wav
# Processing /content/input_dataset/train/unknown/30250_7ea032f3_nohash_3.wav
# Processing /content/input_dataset/train/unknown/13463_eb0676ec_nohash_4.wav
# Processing /content/input_dataset/train/unknown/88022_0b09edd3_nohash_1.wav
# Processing /content/input_dataset/train/unknown/47256_29229c21_nohash_0.wav
# Processing /content/input_dataset/train/unknown/36943_beb458a4_nohash_4.wav
# Processing /content/input_dataset/train/unknown/61812_0b40aa8e_nohash_1.wav
# Processing /content/input_dataset/train/unknown/84328_332d33b1_nohash_0.wav
# Processing /content/input_dataset/train/unknown/100807_23059a35_nohash_0.wav
# Processing /content/input_dataset/train/unknown/60106_f5733968_nohash_3.wav
# Processing /content/input_dataset/train/unknown/87767_2b5e346d_nohash_4.wav
# Processing /content/input_dataset/train/unknown/96668_73124b26_nohash_0.wav
# Processing /content/input_dataset/train/unknown/4011_9a4d12fd_nohash_0.wav
# Processing /content/input_dataset/train/unknown/90469_6c9a1ac2_nohash_1.wav
# Processing /content/input_dataset/train/unknown/6406_dcc012ec_nohash_0.wav
# Processing /content/input_dataset/train/unknown/34668_ea0cf37f_nohash_2.wav
# Processing /content/input_dataset/train/unknown/29627_20fd451f_nohash_0.wav
# Processing /content/input_dataset/train/unknown/33746_b59fe16d_nohash_2.wav
# Processing /content/input_dataset/train/unknown/83806_54b6d355_nohash_0.wav
# Processing /content/input_dataset/train/unknown/22100_c4e00ee9_nohash_4.wav
# Processing /content/input_dataset/train/unknown/79112_25e95412_nohash_5.wav
# Processing /content/input_dataset/train/unknown/84996_f2898d06_nohash_2.wav
# Processing /content/input_dataset/train/unknown/61195_6ceeb9aa_nohash_1.wav
# Processing /content/input_dataset/train/unknown/34063_97e0c576_nohash_1.wav
# Processing /content/input_dataset/train/unknown/25057_3fb8c268_nohash_0.wav
# Processing /content/input_dataset/train/unknown/44272_e10e2cbb_nohash_1.wav
# Processing /content/input_dataset/train/unknown/47541_6fb3d5a7_nohash_1.wav
# Processing /content/input_dataset/train/unknown/7833_6969e51a_nohash_2.wav
# Processing /content/input_dataset/train/unknown/54843_235b444f_nohash_0.wav
# Processing /content/input_dataset/train/unknown/26486_61abbf52_nohash_2.wav
# Processing /content/input_dataset/train/unknown/17289_2bdbe5f7_nohash_2.wav
# Processing /content/input_dataset/train/unknown/44323_cce7416f_nohash_2.wav
# Processing /content/input_dataset/train/unknown/72011_b544d4fd_nohash_1.wav
# Processing /content/input_dataset/train/unknown/52000_1a0f9c63_nohash_1.wav
# Processing /content/input_dataset/train/unknown/23228_113b3fbc_nohash_0.wav
# Processing /content/input_dataset/train/unknown/67565_da040491_nohash_4.wav
# Processing /content/input_dataset/train/unknown/2944_0ac15fe9_nohash_1.wav
# Processing /content/input_dataset/train/unknown/2271_2579e514_nohash_0.wav
# Processing /content/input_dataset/train/unknown/86956_a3255f5c_nohash_0.wav
# Processing /content/input_dataset/train/unknown/27833_5f5eef60_nohash_1.wav
# Processing /content/input_dataset/train/unknown/7453_951cac20_nohash_0.wav
# Processing /content/input_dataset/train/unknown/71285_bb6d4301_nohash_0.wav
# Processing /content/input_dataset/train/unknown/53316_978240e1_nohash_4.wav
# Processing /content/input_dataset/train/unknown/84981_1dc86f91_nohash_1.wav
# Processing /content/input_dataset/train/unknown/18219_fa52ddf6_nohash_2.wav
# Processing /content/input_dataset/train/unknown/71375_b46e8153_nohash_2.wav
# Processing /content/input_dataset/train/unknown/37901_2903efb3_nohash_1.wav
# Processing /content/input_dataset/train/unknown/98344_89947bd7_nohash_0.wav
# Processing /content/input_dataset/train/unknown/9349_3565ca83_nohash_1.wav
# Processing /content/input_dataset/train/unknown/85097_a62f807b_nohash_0.wav
# Processing /content/input_dataset/train/unknown/45499_5aac2efa_nohash_0.wav
# Processing /content/input_dataset/train/unknown/40492_161fcca8_nohash_2.wav
# Processing /content/input_dataset/train/unknown/10091_a7acbbeb_nohash_0.wav
# Processing /content/input_dataset/train/unknown/79119_23da904f_nohash_4.wav
# Processing /content/input_dataset/train/unknown/78769_ee1d8d49_nohash_1.wav
# Processing /content/input_dataset/train/unknown/13031_5f01c798_nohash_0.wav
# Processing /content/input_dataset/train/unknown/95176_86648261_nohash_0.wav
# Processing /content/input_dataset/train/unknown/54156_2aca1e72_nohash_1.wav
# Processing /content/input_dataset/train/unknown/12280_ee4a907f_nohash_1.wav
# Processing /content/input_dataset/train/unknown/96004_1b627376_nohash_0.wav
# Processing /content/input_dataset/train/unknown/36366_487709e7_nohash_0.wav
# Processing /content/input_dataset/train/unknown/30465_211b928a_nohash_4.wav
# Processing /content/input_dataset/train/unknown/12325_63f7a489_nohash_0.wav
# Processing /content/input_dataset/train/unknown/88051_a4ca3afe_nohash_0.wav
# Processing /content/input_dataset/train/unknown/83746_91b03183_nohash_1.wav
# Processing /content/input_dataset/train/unknown/47621_fb8c31a9_nohash_4.wav
# Processing /content/input_dataset/train/unknown/73361_66cff190_nohash_0.wav
# Processing /content/input_dataset/train/unknown/37167_b4ea0d9a_nohash_3.wav
# Processing /content/input_dataset/train/unknown/84925_cb62dbf1_nohash_2.wav
# Processing /content/input_dataset/train/unknown/35550_45864319_nohash_0.wav
# Processing /content/input_dataset/train/unknown/13589_f4386675_nohash_0.wav
# Processing /content/input_dataset/train/unknown/65010_881583a6_nohash_1.wav
# Processing /content/input_dataset/train/unknown/76647_ff2b842e_nohash_0.wav
# Processing /content/input_dataset/train/unknown/10125_ddedba85_nohash_0.wav
# Processing /content/input_dataset/train/unknown/37170_d394ef8e_nohash_0.wav
# Processing /content/input_dataset/train/unknown/68535_aa48c94a_nohash_0.wav
# Processing /content/input_dataset/train/unknown/99491_9f6fbdb4_nohash_0.wav
# Processing /content/input_dataset/train/unknown/29342_c1d39ce8_nohash_3.wav
# Processing /content/input_dataset/train/unknown/46838_db24628d_nohash_2.wav
# Processing /content/input_dataset/train/unknown/10453_53d5b86f_nohash_1.wav
# Processing /content/input_dataset/train/unknown/14104_e5e54cee_nohash_1.wav
# Processing /content/input_dataset/train/unknown/19386_063d48cf_nohash_1.wav
# Processing /content/input_dataset/train/unknown/67871_f00180d0_nohash_0.wav
# Processing /content/input_dataset/train/unknown/17884_73cccfaf_nohash_0.wav
# Processing /content/input_dataset/train/unknown/35900_5b1db3ee_nohash_1.wav
# Processing /content/input_dataset/train/unknown/50867_f2e59fea_nohash_0.wav
# Processing /content/input_dataset/train/unknown/83453_bb05582b_nohash_3.wav
# Processing /content/input_dataset/train/unknown/85235_c50f55b8_nohash_12.wav
# Processing /content/input_dataset/train/unknown/67632_525eaa62_nohash_2.wav
# Processing /content/input_dataset/train/unknown/74926_1ecfb537_nohash_3.wav
# Processing /content/input_dataset/train/unknown/89256_c25a032b_nohash_0.wav
# Processing /content/input_dataset/train/unknown/81680_54b6d355_nohash_3.wav
# Processing /content/input_dataset/train/unknown/3399_a05a90c1_nohash_0.wav
# Processing /content/input_dataset/train/unknown/71368_fde2dee7_nohash_0.wav
# Processing /content/input_dataset/train/unknown/45632_540d8427_nohash_0.wav
# Processing /content/input_dataset/train/unknown/76339_d21fd169_nohash_0.wav
# Processing /content/input_dataset/train/unknown/29355_71d0ded4_nohash_2.wav
# Processing /content/input_dataset/train/unknown/75105_b0bad4a9_nohash_1.wav
# Processing /content/input_dataset/train/unknown/23988_87eff300_nohash_0.wav
# Processing /content/input_dataset/train/unknown/40115_66041c69_nohash_0.wav
# Processing /content/input_dataset/train/unknown/90820_3e3fa7fd_nohash_0.wav
# Processing /content/input_dataset/train/unknown/43417_3903b558_nohash_0.wav
# Processing /content/input_dataset/train/unknown/103082_ed032775_nohash_1.wav
# Processing /content/input_dataset/train/unknown/67971_122c5aa7_nohash_0.wav
# Processing /content/input_dataset/train/unknown/46475_80f056c0_nohash_1.wav
# Processing /content/input_dataset/train/unknown/85494_3c4aa5ef_nohash_2.wav
# Processing /content/input_dataset/train/unknown/46662_c50f55b8_nohash_9.wav
# Processing /content/input_dataset/train/unknown/97117_3a929277_nohash_0.wav
# Processing /content/input_dataset/train/unknown/60099_de3fe344_nohash_0.wav
# Processing /content/input_dataset/train/unknown/3251_b0bad4a9_nohash_3.wav
# Processing /content/input_dataset/train/unknown/13613_ee23b031_nohash_0.wav
# Processing /content/input_dataset/train/unknown/14714_c7aaad67_nohash_0.wav
# Processing /content/input_dataset/train/unknown/24949_cc6ee39b_nohash_3.wav
# Processing /content/input_dataset/train/unknown/84250_1acc97de_nohash_0.wav
# Processing /content/input_dataset/train/unknown/98167_35d1b6ee_nohash_3.wav
# Processing /content/input_dataset/train/unknown/73786_692a88e6_nohash_0.wav
# Processing /content/input_dataset/train/unknown/8345_b5552931_nohash_0.wav
# Processing /content/input_dataset/train/unknown/10827_5e033479_nohash_1.wav
# Processing /content/input_dataset/train/unknown/56426_779de043_nohash_1.wav
# Processing /content/input_dataset/train/unknown/90486_e0c782d5_nohash_1.wav
# Processing /content/input_dataset/train/unknown/68633_462dca36_nohash_1.wav
# Processing /content/input_dataset/train/unknown/12745_e71a9381_nohash_3.wav
# Processing /content/input_dataset/train/unknown/94875_64e48f55_nohash_2.wav
# Processing /content/input_dataset/train/unknown/34244_eee5e541_nohash_1.wav
# Processing /content/input_dataset/train/unknown/101479_72320401_nohash_1.wav
# Processing /content/input_dataset/train/unknown/61328_72e382bd_nohash_0.wav
# Processing /content/input_dataset/train/unknown/73237_197f4153_nohash_1.wav
# Processing /content/input_dataset/train/unknown/33962_a108341b_nohash_1.wav
# Processing /content/input_dataset/train/unknown/98313_8a5acefd_nohash_0.wav
# Processing /content/input_dataset/train/unknown/15590_525eaa62_nohash_2.wav
# Processing /content/input_dataset/train/unknown/97909_f2e59fea_nohash_2.wav
# Processing /content/input_dataset/train/unknown/99735_b76f6088_nohash_0.wav
# Processing /content/input_dataset/train/unknown/98567_ce0cb033_nohash_1.wav
# Processing /content/input_dataset/train/unknown/72891_471a0925_nohash_1.wav
# Processing /content/input_dataset/train/unknown/62929_742d6431_nohash_1.wav
# Processing /content/input_dataset/train/unknown/22581_0ea9c8ce_nohash_4.wav
# Processing /content/input_dataset/train/unknown/98658_3efa7ec4_nohash_0.wav
# Processing /content/input_dataset/train/unknown/63317_cb2929ce_nohash_5.wav
# Processing /content/input_dataset/train/unknown/89838_caedb73a_nohash_0.wav
# Processing /content/input_dataset/train/unknown/67532_3a3ee7ed_nohash_3.wav
# Processing /content/input_dataset/train/unknown/6156_51f7a034_nohash_1.wav
# Processing /content/input_dataset/train/unknown/5250_30f31e42_nohash_0.wav
# Processing /content/input_dataset/train/unknown/46607_5f8097e1_nohash_0.wav
# Processing /content/input_dataset/train/unknown/43017_c1e0e8e3_nohash_3.wav
# Processing /content/input_dataset/train/unknown/14667_dca2797e_nohash_0.wav
# Processing /content/input_dataset/train/unknown/65786_bd76a7fd_nohash_1.wav
# Processing /content/input_dataset/train/unknown/64312_190821dc_nohash_0.wav
# Processing /content/input_dataset/train/unknown/26874_c634a189_nohash_3.wav
# Processing /content/input_dataset/train/unknown/34335_e4be0cf6_nohash_0.wav
# Processing /content/input_dataset/train/unknown/65180_9a3f97f8_nohash_1.wav
# Processing /content/input_dataset/train/unknown/29565_afb9e62e_nohash_0.wav
# Processing /content/input_dataset/train/unknown/15587_39a12648_nohash_0.wav
# Processing /content/input_dataset/train/unknown/58566_30060aba_nohash_1.wav
# Processing /content/input_dataset/train/unknown/35318_9d7036f9_nohash_0.wav
# Processing /content/input_dataset/train/unknown/43603_c4533c47_nohash_0.wav
# Processing /content/input_dataset/train/unknown/7932_fe31cb13_nohash_1.wav
# Processing /content/input_dataset/train/unknown/51910_b7a6f709_nohash_1.wav
# Processing /content/input_dataset/train/unknown/89005_798f702a_nohash_0.wav
# Processing /content/input_dataset/train/unknown/34002_69f609ec_nohash_0.wav
# Processing /content/input_dataset/train/unknown/56228_ee1d8d49_nohash_0.wav
# Processing /content/input_dataset/train/unknown/81594_3e549219_nohash_1.wav
# Processing /content/input_dataset/train/unknown/87407_dabf67d9_nohash_0.wav
# Processing /content/input_dataset/train/unknown/79874_d9aa8c90_nohash_2.wav
# Processing /content/input_dataset/train/unknown/99307_bab36420_nohash_1.wav
# Processing /content/input_dataset/train/unknown/78064_b69002d4_nohash_0.wav
# Processing /content/input_dataset/train/unknown/22024_a77fbcfd_nohash_1.wav
# Processing /content/input_dataset/train/unknown/68592_f44f440f_nohash_2.wav
# Processing /content/input_dataset/train/unknown/97425_e9abfe31_nohash_1.wav
# Processing /content/input_dataset/train/unknown/23777_5744b6a7_nohash_0.wav
# Processing /content/input_dataset/train/unknown/87316_ac9dee0e_nohash_4.wav
# Processing /content/input_dataset/train/unknown/103793_89947bd7_nohash_0.wav
# Processing /content/input_dataset/train/unknown/61000_b29f8b23_nohash_1.wav
# Processing /content/input_dataset/train/unknown/59937_d0858dce_nohash_1.wav
# Processing /content/input_dataset/train/unknown/79649_fcb25a78_nohash_0.wav
# Processing /content/input_dataset/train/unknown/14394_7cf14c54_nohash_1.wav
# Processing /content/input_dataset/train/unknown/59977_1496195a_nohash_3.wav
# Processing /content/input_dataset/train/unknown/2677_1851e33b_nohash_0.wav
# Processing /content/input_dataset/train/unknown/49182_f0522ff4_nohash_0.wav
# Processing /content/input_dataset/train/unknown/25788_c50f55b8_nohash_2.wav
# Processing /content/input_dataset/train/unknown/50332_079dfce3_nohash_1.wav
# Processing /content/input_dataset/train/unknown/43690_1496195a_nohash_1.wav
# Processing /content/input_dataset/train/unknown/42190_b69002d4_nohash_1.wav
# Processing /content/input_dataset/train/unknown/87380_321aba74_nohash_1.wav
# Processing /content/input_dataset/train/unknown/77729_e3e0f145_nohash_0.wav
# Processing /content/input_dataset/train/unknown/51521_3ec05c3d_nohash_0.wav
# Processing /content/input_dataset/train/unknown/99144_29dce108_nohash_0.wav
# Processing /content/input_dataset/train/unknown/82940_66cff190_nohash_1.wav
# Processing /content/input_dataset/train/unknown/73092_72aa7259_nohash_0.wav
# Processing /content/input_dataset/train/unknown/20223_74241b28_nohash_2.wav
# Processing /content/input_dataset/train/unknown/73963_050170cb_nohash_4.wav
# Processing /content/input_dataset/train/unknown/76098_6124b431_nohash_0.wav
# Processing /content/input_dataset/train/unknown/44090_8f0d3c27_nohash_1.wav
# Processing /content/input_dataset/train/unknown/69511_53fd1780_nohash_2.wav
# Processing /content/input_dataset/train/unknown/100139_fb7eb481_nohash_2.wav
# Processing /content/input_dataset/train/unknown/10297_9beccfc8_nohash_0.wav
# Processing /content/input_dataset/train/unknown/49439_72aa7259_nohash_0.wav
# Processing /content/input_dataset/train/unknown/22925_324210dd_nohash_2.wav
# Processing /content/input_dataset/train/unknown/77199_c24d96eb_nohash_0.wav
# Processing /content/input_dataset/train/unknown/41379_cb2929ce_nohash_8.wav
# Processing /content/input_dataset/train/unknown/11060_22aa3665_nohash_0.wav
# Processing /content/input_dataset/train/unknown/59498_5e3dde6b_nohash_0.wav
# Processing /content/input_dataset/train/unknown/18026_821b64cc_nohash_0.wav
# Processing /content/input_dataset/train/unknown/101065_529eda42_nohash_0.wav
# Processing /content/input_dataset/train/unknown/99972_b66f4f93_nohash_7.wav
# Processing /content/input_dataset/train/unknown/102385_73f20b00_nohash_2.wav
# Processing /content/input_dataset/train/unknown/68937_33246bc2_nohash_0.wav
# Processing /content/input_dataset/train/unknown/72886_80f056c0_nohash_0.wav
# Processing /content/input_dataset/train/unknown/43267_df038de4_nohash_1.wav
# Processing /content/input_dataset/train/unknown/41645_f618568f_nohash_0.wav
# Processing /content/input_dataset/train/unknown/30150_b00c4c53_nohash_0.wav
# Processing /content/input_dataset/train/unknown/59199_da15e796_nohash_0.wav
# Processing /content/input_dataset/train/unknown/11036_9b6c08ba_nohash_0.wav
# Processing /content/input_dataset/train/unknown/28232_d5b963aa_nohash_2.wav
# Processing /content/input_dataset/train/unknown/101473_322d17d3_nohash_1.wav
# Processing /content/input_dataset/train/unknown/52043_0d6d7360_nohash_0.wav
# Processing /content/input_dataset/train/unknown/89963_21832144_nohash_0.wav
# Processing /content/input_dataset/train/unknown/61966_28e47b1a_nohash_1.wav
# Processing /content/input_dataset/train/unknown/42664_437455be_nohash_0.wav
# Processing /content/input_dataset/train/unknown/14977_964e8cfd_nohash_4.wav
# Processing /content/input_dataset/train/unknown/98934_d21fd169_nohash_0.wav
# Processing /content/input_dataset/train/unknown/59357_d3a18257_nohash_0.wav
# Processing /content/input_dataset/train/unknown/22356_8781f4c1_nohash_0.wav
# Processing /content/input_dataset/train/unknown/25650_012187a4_nohash_0.wav
# Processing /content/input_dataset/train/unknown/8090_471a0925_nohash_3.wav
# Processing /content/input_dataset/train/unknown/54573_dac8b7f9_nohash_1.wav
# Processing /content/input_dataset/train/unknown/3612_4beff0c5_nohash_0.wav
# Processing /content/input_dataset/train/unknown/78046_a7200079_nohash_2.wav
# Processing /content/input_dataset/train/unknown/95199_9b02d503_nohash_2.wav
# Processing /content/input_dataset/train/unknown/21522_676f8138_nohash_3.wav
# Processing /content/input_dataset/train/unknown/54699_c7124b73_nohash_0.wav
# Processing /content/input_dataset/train/unknown/69755_563aa4e6_nohash_0.wav
# Processing /content/input_dataset/train/unknown/66236_c9e251d2_nohash_1.wav
# Processing /content/input_dataset/train/unknown/20239_13199b79_nohash_1.wav
# Processing /content/input_dataset/train/unknown/46825_190821dc_nohash_0.wav
# Processing /content/input_dataset/train/unknown/27899_03cf93b1_nohash_0.wav
# Processing /content/input_dataset/train/unknown/18610_0132a06d_nohash_1.wav
# Processing /content/input_dataset/train/unknown/75387_b3849d6e_nohash_0.wav
# Processing /content/input_dataset/train/unknown/3794_1b63157b_nohash_0.wav
# Processing /content/input_dataset/train/unknown/55864_6c0f6493_nohash_0.wav
# Processing /content/input_dataset/train/unknown/43987_5195f0ec_nohash_0.wav
# Processing /content/input_dataset/train/unknown/79898_40115b19_nohash_0.wav
# Processing /content/input_dataset/train/unknown/10989_d1214f15_nohash_0.wav
# Processing /content/input_dataset/train/unknown/66530_1b42b551_nohash_3.wav
# Processing /content/input_dataset/train/unknown/37819_978240e1_nohash_3.wav
# Processing /content/input_dataset/train/unknown/97887_616420be_nohash_0.wav
# Processing /content/input_dataset/train/unknown/53572_de3fe344_nohash_0.wav
# Processing /content/input_dataset/train/unknown/58103_ec989d6d_nohash_2.wav
# Processing /content/input_dataset/train/unknown/499_ecbd8d66_nohash_1.wav
# Processing /content/input_dataset/train/unknown/16748_43f57297_nohash_1.wav
# Processing /content/input_dataset/train/unknown/100976_2a1f4853_nohash_3.wav
# Processing /content/input_dataset/train/unknown/9394_5d0ab165_nohash_0.wav
# Processing /content/input_dataset/train/unknown/5101_9448c397_nohash_1.wav
# Processing /content/input_dataset/train/unknown/95086_8a28231e_nohash_3.wav
# Processing /content/input_dataset/train/unknown/23912_e11fbc6e_nohash_3.wav
# Processing /content/input_dataset/train/unknown/4036_16d41d07_nohash_1.wav
# Processing /content/input_dataset/train/unknown/32421_de89e2ca_nohash_4.wav
# Processing /content/input_dataset/train/unknown/74946_542f38a2_nohash_0.wav
# Processing /content/input_dataset/train/unknown/78861_b97c9f77_nohash_2.wav
# Processing /content/input_dataset/train/unknown/86934_87d5e978_nohash_4.wav
# Processing /content/input_dataset/train/unknown/60424_1afd49bf_nohash_2.wav
# Processing /content/input_dataset/train/unknown/64718_30f6e665_nohash_1.wav
# Processing /content/input_dataset/train/unknown/51724_31583d30_nohash_2.wav
# Processing /content/input_dataset/train/unknown/70563_7fb8d703_nohash_0.wav
# Processing /content/input_dataset/train/unknown/62945_9a76f8c3_nohash_0.wav
# Processing /content/input_dataset/train/unknown/103592_616420be_nohash_0.wav
# Processing /content/input_dataset/train/unknown/18884_1a994c9f_nohash_1.wav
# Processing /content/input_dataset/train/unknown/36382_25e95412_nohash_0.wav
# Processing /content/input_dataset/train/unknown/62722_7622d95b_nohash_2.wav
# Processing /content/input_dataset/train/unknown/64086_e9bc5cc2_nohash_3.wav
# Processing /content/input_dataset/train/unknown/23242_559bc36a_nohash_1.wav
# Processing /content/input_dataset/train/unknown/36848_cc3d1613_nohash_0.wav
# Processing /content/input_dataset/train/unknown/91303_9ff2d2f4_nohash_1.wav
# Processing /content/input_dataset/train/unknown/71072_d1214f15_nohash_1.wav
# Processing /content/input_dataset/train/unknown/80424_e95c70e2_nohash_0.wav
# Processing /content/input_dataset/train/unknown/48748_9448c397_nohash_2.wav
# Processing /content/input_dataset/train/unknown/58981_95ba4996_nohash_2.wav
# Processing /content/input_dataset/train/unknown/83563_ca4912b6_nohash_2.wav
# Processing /content/input_dataset/train/unknown/3505_62ccd358_nohash_0.wav
# Processing /content/input_dataset/train/unknown/59142_1e02ffc5_nohash_4.wav
# Processing /content/input_dataset/train/unknown/35050_3f45a0cf_nohash_0.wav
# Processing /content/input_dataset/train/unknown/102265_9b02d503_nohash_0.wav
# Processing /content/input_dataset/train/unknown/4768_8bf6acb9_nohash_1.wav
# Processing /content/input_dataset/train/unknown/42704_caf1803e_nohash_0.wav
# Processing /content/input_dataset/train/unknown/95747_3c1e12cf_nohash_1.wav
# Processing /content/input_dataset/train/unknown/85609_d9aa8c90_nohash_0.wav
# Processing /content/input_dataset/train/unknown/7467_a8ee11c7_nohash_0.wav
# Processing /content/input_dataset/train/unknown/16376_32ad5b65_nohash_1.wav
# Processing /content/input_dataset/train/unknown/56256_c08585c1_nohash_0.wav
# Processing /content/input_dataset/train/unknown/9164_332d33b1_nohash_0.wav
# Processing /content/input_dataset/train/unknown/60568_c2dccf38_nohash_1.wav
# Processing /content/input_dataset/train/unknown/97961_1c84a139_nohash_3.wav
# Processing /content/input_dataset/train/unknown/41661_5170b77f_nohash_1.wav
# Processing /content/input_dataset/train/unknown/12126_becd5a53_nohash_2.wav
# Processing /content/input_dataset/train/unknown/87847_ccea893d_nohash_1.wav
# Processing /content/input_dataset/train/unknown/74382_763188c4_nohash_3.wav
# Processing /content/input_dataset/train/unknown/63337_538e1856_nohash_0.wav
# Processing /content/input_dataset/train/unknown/51058_84bf12ff_nohash_0.wav
# ...
# Processing /content/input_dataset/train/unknown/93846_d962e5ac_nohash_0.wav
# Processing /content/input_dataset/train/unknown/98336_17f0e206_nohash_0.wav
# Processing /content/input_dataset/train/unknown/90371_a60a09cf_nohash_0.wav
# Processing /content/input_dataset/train/unknown/35744_e71a9381_nohash_1.wav
# Processing /content/input_dataset/train/unknown/6123_39dce8cc_nohash_1.wav
# Processing /content/input_dataset/train/unknown/63529_35d1b6ee_nohash_0.wav
# Processing /content/input_dataset/train/unknown/3734_88f8a99c_nohash_0.wav
# Processing /content/input_dataset/train/unknown/92879_1a6eca98_nohash_0.wav
# Processing /content/input_dataset/train/unknown/70577_8b775397_nohash_0.wav
# Processing /content/input_dataset/train/unknown/98524_31583d30_nohash_1.wav
# Processing /content/input_dataset/train/unknown/44885_6c6aa323_nohash_0.wav
# Processing /content/input_dataset/train/unknown/91763_ec21c46b_nohash_0.wav
# Processing /content/input_dataset/train/unknown/93624_ef3367d9_nohash_2.wav
# Processing /content/input_dataset/train/unknown/86499_3a3ee7ed_nohash_3.wav
# Processing /content/input_dataset/train/unknown/43255_b575b5fb_nohash_0.wav
# Processing /content/input_dataset/train/unknown/70016_25040e85_nohash_0.wav
# Processing /content/input_dataset/train/unknown/15790_52e228e9_nohash_0.wav
# Processing /content/input_dataset/train/unknown/78869_87070229_nohash_4.wav
# Processing /content/input_dataset/train/unknown/47561_ae5578f4_nohash_0.wav
# Processing /content/input_dataset/train/unknown/83398_679463fc_nohash_3.wav
# Processing /content/input_dataset/train/unknown/85209_017c4098_nohash_0.wav
# Processing /content/input_dataset/train/unknown/87499_37dca74f_nohash_2.wav
# Processing /content/input_dataset/train/unknown/102858_39833acb_nohash_1.wav
# Processing /content/input_dataset/train/unknown/46209_28460a60_nohash_1.wav
# Processing /content/input_dataset/train/unknown/34958_5f9cd2eb_nohash_1.wav
# Processing /content/input_dataset/train/unknown/8731_257251e0_nohash_0.wav
# Processing /content/input_dataset/train/unknown/68523_dae01802_nohash_0.wav
# Processing /content/input_dataset/train/unknown/30380_d0faf7e4_nohash_2.wav
# Processing /content/input_dataset/train/unknown/65514_3477fab6_nohash_0.wav
# Processing /content/input_dataset/train/unknown/24215_e71a9381_nohash_3.wav
# Processing /content/input_dataset/train/unknown/29023_a4ca3afe_nohash_0.wav
# Processing /content/input_dataset/train/unknown/41539_81332c92_nohash_0.wav
# Processing /content/input_dataset/train/unknown/98606_b66f4f93_nohash_6.wav
# Processing /content/input_dataset/train/unknown/29248_34e8c726_nohash_0.wav
# Processing /content/input_dataset/train/unknown/78509_76e53db9_nohash_0.wav
# Processing /content/input_dataset/train/unknown/94134_c099668c_nohash_0.wav
# Processing /content/input_dataset/train/unknown/5185_17f0e206_nohash_1.wav
# Processing /content/input_dataset/train/unknown/100395_b414c653_nohash_2.wav
# Processing /content/input_dataset/train/unknown/17947_0bfec55f_nohash_0.wav
# Processing /content/input_dataset/train/unknown/12825_59c3a7f2_nohash_0.wav
# Processing /content/input_dataset/train/unknown/69759_e269bac0_nohash_0.wav
# Processing /content/input_dataset/train/unknown/46274_5f5eef60_nohash_0.wav
# Processing /content/input_dataset/train/unknown/84904_195c120a_nohash_3.wav
# Processing /content/input_dataset/train/unknown/57874_e0315cf6_nohash_3.wav
# Processing /content/input_dataset/train/unknown/90399_563aa4e6_nohash_0.wav
# Processing /content/input_dataset/train/unknown/71018_a3fc7884_nohash_0.wav
# Processing /content/input_dataset/train/unknown/89366_171edea9_nohash_2.wav
# Processing /content/input_dataset/train/unknown/56431_f5e44d34_nohash_0.wav
# Processing /content/input_dataset/train/unknown/42726_f5e44d34_nohash_0.wav
# Processing /content/input_dataset/train/unknown/34265_f2dd248e_nohash_1.wav
# Processing /content/input_dataset/train/unknown/17442_becd5a53_nohash_1.wav
# Processing /content/input_dataset/train/unknown/24765_ab71c9a7_nohash_2.wav
# Processing /content/input_dataset/train/unknown/18900_8e05039f_nohash_2.wav
# Processing /content/input_dataset/train/unknown/23408_b8b8cb52_nohash_0.wav
# Processing /content/input_dataset/train/unknown/50514_a7545b9f_nohash_0.wav
# Processing /content/input_dataset/train/unknown/40868_578d3efb_nohash_3.wav
# Processing /content/input_dataset/train/unknown/62733_86fa2dcd_nohash_0.wav
# Processing /content/input_dataset/train/unknown/80548_7211390b_nohash_0.wav
# Processing /content/input_dataset/train/unknown/75327_89d6d11e_nohash_1.wav
# Processing /content/input_dataset/train/unknown/27738_dae01802_nohash_3.wav
# Processing /content/input_dataset/train/unknown/6431_c634a189_nohash_2.wav
# Processing /content/input_dataset/train/unknown/58404_be7a5b2d_nohash_2.wav
# Processing /content/input_dataset/train/unknown/88396_e82914c0_nohash_0.wav
# Processing /content/input_dataset/train/unknown/61651_de89e2ca_nohash_2.wav
# Processing /content/input_dataset/train/unknown/32327_529eda42_nohash_1.wav
# Processing /content/input_dataset/train/unknown/30145_6f2c6f7e_nohash_0.wav
# Processing /content/input_dataset/train/unknown/1431_4e99c1b7_nohash_0.wav
# Processing /content/input_dataset/train/unknown/100987_9ff2d2f4_nohash_4.wav
# Processing /content/input_dataset/train/unknown/102372_42f81601_nohash_0.wav
# Processing /content/input_dataset/train/unknown/90865_8e05039f_nohash_3.wav
# Processing /content/input_dataset/train/unknown/37508_6d1dcca6_nohash_0.wav
# Processing /content/input_dataset/train/unknown/92443_07089da9_nohash_3.wav
# Processing /content/input_dataset/train/unknown/15047_9c06a3f3_nohash_0.wav
# Processing /content/input_dataset/train/unknown/39376_c39703ec_nohash_0.wav
# Processing /content/input_dataset/train/unknown/25705_92521ccc_nohash_1.wav
# Processing /content/input_dataset/train/unknown/18074_825f450d_nohash_0.wav
# Processing /content/input_dataset/train/unknown/48844_71aa5b54_nohash_0.wav
# Processing /content/input_dataset/train/unknown/14800_742d6431_nohash_2.wav
# Processing /content/input_dataset/train/unknown/44182_c33682f0_nohash_0.wav
# Processing /content/input_dataset/train/unknown/33633_7d6b4b10_nohash_2.wav
# Processing /content/input_dataset/train/unknown/71021_96105282_nohash_0.wav
# Processing /content/input_dataset/train/unknown/69926_80c17118_nohash_1.wav
# Processing /content/input_dataset/train/unknown/73306_d312f481_nohash_1.wav
# Processing /content/input_dataset/train/unknown/89651_e9abfe31_nohash_1.wav
# Processing /content/input_dataset/train/unknown/62107_2da58b32_nohash_1.wav
# Processing /content/input_dataset/train/unknown/84592_1474273a_nohash_1.wav
# Processing /content/input_dataset/train/unknown/26672_686d030b_nohash_1.wav
# Processing /content/input_dataset/train/unknown/38637_53578f4e_nohash_1.wav
# Processing /content/input_dataset/train/unknown/10190_aba19127_nohash_0.wav
# Processing /content/input_dataset/train/unknown/69931_ad9de4dd_nohash_0.wav
# Processing /content/input_dataset/train/unknown/27020_1dc86f91_nohash_3.wav
# Processing /content/input_dataset/train/unknown/73744_2151b09a_nohash_0.wav
# Processing /content/input_dataset/train/unknown/90918_51055bda_nohash_2.wav
# Processing /content/input_dataset/train/unknown/22403_2903efb3_nohash_0.wav
# Processing /content/input_dataset/train/unknown/89515_978240e1_nohash_1.wav
# Processing /content/input_dataset/train/unknown/25743_de4f7798_nohash_0.wav
# Processing /content/input_dataset/train/unknown/85661_bd76a7fd_nohash_3.wav
# Processing /content/input_dataset/train/unknown/55194_b11a05d2_nohash_1.wav
# Processing /content/input_dataset/train/unknown/36622_b8874962_nohash_2.wav
# Processing /content/input_dataset/train/unknown/38482_7117fb6d_nohash_3.wav
# Processing /content/input_dataset/train/unknown/23429_708b8d51_nohash_1.wav
# Processing /content/input_dataset/train/unknown/8313_ca48dc76_nohash_0.wav
# Processing /content/input_dataset/train/unknown/18612_5fadb538_nohash_2.wav
# Processing /content/input_dataset/train/unknown/21149_ec201020_nohash_1.wav
# Processing /content/input_dataset/train/unknown/1374_dca2797e_nohash_0.wav
# Processing /content/input_dataset/train/unknown/51550_7846fd85_nohash_0.wav
# Processing /content/input_dataset/train/unknown/96996_a50a98d2_nohash_0.wav
# Processing /content/input_dataset/train/unknown/55219_51055bda_nohash_4.wav
# Processing /content/input_dataset/train/unknown/16009_f19c1390_nohash_0.wav
# Processing /content/input_dataset/train/unknown/34157_fb7eb481_nohash_0.wav
# Processing /content/input_dataset/train/unknown/27450_a0f93943_nohash_0.wav
# Processing /content/input_dataset/train/unknown/76707_6ace4fe1_nohash_0.wav
# Processing /content/input_dataset/train/unknown/84688_332d33b1_nohash_2.wav
# Processing /content/input_dataset/train/unknown/28752_02ade946_nohash_3.wav
# Processing /content/input_dataset/train/unknown/15348_cc592808_nohash_0.wav
# Processing /content/input_dataset/train/unknown/83588_a1e71565_nohash_0.wav
# Processing /content/input_dataset/train/unknown/8694_a2cc5444_nohash_0.wav
# Processing /content/input_dataset/train/unknown/57854_42ccb57a_nohash_1.wav
# Processing /content/input_dataset/train/unknown/86646_d0745d72_nohash_0.wav
# Processing /content/input_dataset/train/unknown/73855_c5570933_nohash_0.wav
# Processing /content/input_dataset/train/unknown/74425_7eee5973_nohash_0.wav
# Processing /content/input_dataset/train/unknown/20177_6cb6eee7_nohash_0.wav
# Processing /content/input_dataset/train/unknown/62463_542f38a2_nohash_2.wav
# Processing /content/input_dataset/train/unknown/3234_3e2ba5f7_nohash_1.wav
# Processing /content/input_dataset/train/unknown/77207_f6af2457_nohash_0.wav
# Processing /content/input_dataset/train/unknown/66086_53fd1780_nohash_1.wav
# Processing /content/input_dataset/train/unknown/4705_98ea0818_nohash_5.wav
# Processing /content/input_dataset/train/unknown/80882_6b889021_nohash_0.wav
# Processing /content/input_dataset/train/unknown/44575_b2ae3928_nohash_2.wav
# Processing /content/input_dataset/train/unknown/61837_9d050657_nohash_0.wav
# Processing /content/input_dataset/train/unknown/31987_778a4a01_nohash_0.wav
# Processing /content/input_dataset/train/unknown/36129_bbc30633_nohash_1.wav
# Processing /content/input_dataset/train/unknown/59658_bdd22e4d_nohash_3.wav
# Processing /content/input_dataset/train/unknown/9671_c1eebc0b_nohash_0.wav
# Processing /content/input_dataset/train/unknown/102390_e71a9381_nohash_1.wav
# Processing /content/input_dataset/train/unknown/17003_c08e5058_nohash_0.wav
# Processing /content/input_dataset/train/unknown/39314_fb01a182_nohash_0.wav
# Processing /content/input_dataset/train/unknown/39892_590750e8_nohash_0.wav
# Processing /content/input_dataset/train/unknown/27250_44c201dd_nohash_2.wav
# Processing /content/input_dataset/train/unknown/4315_c2dccf38_nohash_2.wav
# Processing /content/input_dataset/train/unknown/74602_0f3f64d5_nohash_1.wav
# Processing /content/input_dataset/train/unknown/40350_8c3c4715_nohash_0.wav
# Processing /content/input_dataset/train/unknown/14302_ed032775_nohash_1.wav
# Processing /content/input_dataset/train/unknown/95853_eeaf97c3_nohash_1.wav
# Processing /content/input_dataset/train/unknown/5451_c351e611_nohash_4.wav
# Processing /content/input_dataset/train/unknown/39030_2fee065a_nohash_0.wav
# Processing /content/input_dataset/train/unknown/20957_c5a1e46c_nohash_2.wav
# Processing /content/input_dataset/train/unknown/24767_093f65a1_nohash_0.wav
# Processing /content/input_dataset/train/unknown/46071_a1a59b72_nohash_0.wav
# Processing /content/input_dataset/train/unknown/71941_6b81fead_nohash_0.wav
# Processing /content/input_dataset/train/unknown/71577_951cac20_nohash_0.wav
# Processing /content/input_dataset/train/unknown/1049_1b5ba788_nohash_0.wav
# Processing /content/input_dataset/train/unknown/84812_bbf38549_nohash_1.wav
# Processing /content/input_dataset/train/unknown/23190_89947bd7_nohash_3.wav
# Processing /content/input_dataset/train/unknown/44440_64f1c742_nohash_0.wav
# Processing /content/input_dataset/train/unknown/62594_0ea9c8ce_nohash_0.wav
# Processing /content/input_dataset/train/unknown/18067_4f2be90f_nohash_0.wav
# Processing /content/input_dataset/train/unknown/13066_80b8eab4_nohash_1.wav
# Processing /content/input_dataset/train/unknown/52788_0c2d2ffa_nohash_0.wav
# Processing /content/input_dataset/train/unknown/17683_196e84b7_nohash_1.wav
# Processing /content/input_dataset/train/unknown/48812_ca4d5368_nohash_0.wav
# Processing /content/input_dataset/train/unknown/52419_43f57297_nohash_0.wav
# Processing /content/input_dataset/train/unknown/102593_0ea9c8ce_nohash_2.wav
# Processing /content/input_dataset/train/unknown/49789_5aac2efa_nohash_1.wav
# Processing /content/input_dataset/train/unknown/49859_9735764a_nohash_0.wav
# Processing /content/input_dataset/train/unknown/2477_0397ecda_nohash_0.wav
# Processing /content/input_dataset/train/unknown/68026_778a4a01_nohash_0.wav
# Processing /content/input_dataset/train/unknown/71781_62ccd358_nohash_1.wav
# Processing /content/input_dataset/train/unknown/72063_5b1db3ee_nohash_0.wav
# Processing /content/input_dataset/train/unknown/71362_721f767c_nohash_0.wav
# Processing /content/input_dataset/train/unknown/83864_a7216980_nohash_0.wav
# Processing /content/input_dataset/train/unknown/83505_c38720cb_nohash_0.wav
# Processing /content/input_dataset/train/unknown/21813_f192e6b4_nohash_2.wav
# Processing /content/input_dataset/train/unknown/79140_97addd88_nohash_1.wav
# Processing /content/input_dataset/train/unknown/101235_6c968bd9_nohash_0.wav
# Processing /content/input_dataset/train/unknown/18453_902258bb_nohash_1.wav
# Processing /content/input_dataset/train/unknown/82508_7f9eb952_nohash_1.wav
# Processing /content/input_dataset/train/unknown/40373_c9e251d2_nohash_0.wav
# Processing /content/input_dataset/train/unknown/40153_0a196374_nohash_0.wav
# Processing /content/input_dataset/train/unknown/67479_af790082_nohash_1.wav
# Processing /content/input_dataset/train/unknown/76755_e7bcee8a_nohash_1.wav
# Processing /content/input_dataset/train/unknown/42159_96a48d28_nohash_2.wav
# Processing /content/input_dataset/train/unknown/39599_31267b59_nohash_1.wav
# Processing /content/input_dataset/train/unknown/96515_3108acca_nohash_1.wav
# Processing /content/input_dataset/train/unknown/88565_24694eb6_nohash_0.wav
# Processing /content/input_dataset/train/unknown/17083_67961766_nohash_0.wav
# Processing /content/input_dataset/train/unknown/19480_645ed69d_nohash_2.wav
# Processing /content/input_dataset/train/unknown/38272_099d52ad_nohash_1.wav
# Processing /content/input_dataset/train/unknown/13171_30f31e42_nohash_0.wav
# Processing /content/input_dataset/train/unknown/57476_db24628d_nohash_4.wav
# Processing /content/input_dataset/train/unknown/65227_5c39594f_nohash_2.wav
# Processing /content/input_dataset/train/unknown/35276_cd8b1781_nohash_0.wav
# Processing /content/input_dataset/train/unknown/101008_ff4ed4f3_nohash_2.wav
# Processing /content/input_dataset/train/unknown/45940_48a8a69d_nohash_0.wav
# Processing /content/input_dataset/train/unknown/25347_2748cce7_nohash_2.wav
# Processing /content/input_dataset/train/unknown/39744_c24d96eb_nohash_0.wav
# Processing /content/input_dataset/train/unknown/20940_da584bc0_nohash_2.wav
# Processing /content/input_dataset/train/unknown/22762_9fac5701_nohash_4.wav
# Processing /content/input_dataset/train/unknown/248_4290ca61_nohash_0.wav
# Processing /content/input_dataset/train/unknown/11781_cc8b3228_nohash_0.wav
# Processing /content/input_dataset/train/unknown/66848_460209ac_nohash_2.wav
# Processing /content/input_dataset/train/unknown/26562_978240e1_nohash_1.wav
# Processing /content/input_dataset/train/unknown/28267_28460a60_nohash_0.wav
# Processing /content/input_dataset/train/unknown/75476_eeaf97c3_nohash_0.wav
# Processing /content/input_dataset/train/unknown/57239_5b26c81b_nohash_0.wav
# Processing /content/input_dataset/train/unknown/25904_4b3a7ad5_nohash_1.wav
# Processing /content/input_dataset/train/unknown/40240_211b928a_nohash_0.wav
# Processing /content/input_dataset/train/unknown/87898_d9aa8c90_nohash_0.wav
# Processing /content/input_dataset/train/unknown/47341_840c366d_nohash_0.wav
# Processing /content/input_dataset/train/unknown/18592_692a88e6_nohash_2.wav

# %%
training_list = getSampleList(train_dir)
validation_list = getSampleList(val_dir)
test_list = getSampleList(test_dir)

print("Number of samples after data augmentation:")
print("Training samples: " + str(len(training_list)))
print("Validation samples: " + str(len(validation_list)))
print("Testing samples: " + str(len(test_list)))
print("---")
print("Training set:")
printNumSamples(train_dir)
# Out:
# Number of samples after data augmentation:
# Training samples: 8109
# Validation samples: 1013
# Testing samples: 1015
# ---
# Training set:
# Number of samples in class "silence": 4892
# Number of samples in class "unknown": 1600
# Number of samples in class "sheila": 1617

# %% [markdown]
# ## NPZ Archives Generator

# %%
SAMPLE_RATE = 16000
CLIP_DURATION_MS = 1000
WINDOW_SIZE_MS = 30
WINDOW_STRIDE = 20
FEATURE_BIN_COUNT = 40
PREPROCESS = 'micro'

TF_SESS = tf.compat.v1.InteractiveSession()

custom_model_settings = models.prepare_model_settings(
      0, SAMPLE_RATE, CLIP_DURATION_MS, WINDOW_SIZE_MS,
      WINDOW_STRIDE, FEATURE_BIN_COUNT, PREPROCESS)

custom_audio_processor = input_data.AudioProcessor(None, None, 0, 0, '', 0, 0,
                                                    custom_model_settings, None)

# %%
spectrogram_shape = (49,40,1)

def generate_data(samples_list, destpath):
  sample_number = len(samples_list)
  X = np.empty((sample_number, *spectrogram_shape))
  y = np.empty((sample_number, 1))

  # Generate data
  for i, sample in enumerate(samples_list):
      # Store sample
      sample_preprocessed = custom_audio_processor.get_features_for_wav(
          sample, custom_model_settings, TF_SESS)
      mfcc = np.asarray(sample_preprocessed).reshape(*spectrogram_shape)
      X[i,] = (mfcc / 13.0) - 1.0
      # Store class
      filepath = os.path.dirname(sample)
      classname = os.path.basename(filepath)
      y[i] = wanted_words.index(classname)

  np.savez_compressed(destpath, X, y)

# %%
training_dataset_npz = "/content/train.npz"
testing_dataset_npz = "/content/testing.npz"
validation_dataset_npz = "/content/validation.npz"
representative_dataset_npz = "/content/representative.npz"

generate_data(training_list, training_dataset_npz)
generate_data(test_list, testing_dataset_npz)
generate_data(validation_list, validation_dataset_npz)
generate_data(representative_list, representative_dataset_npz)

# %%
import json

# Data to be written
dictionary = {
    "classes": wanted_words,
    "train_samples_num": len(training_list),
    "testing_samples_num": len(test_list),
    "validation_samples_num": len(validation_list),
    "representative_samples_num": len(representative_list),
    "data_shape": spectrogram_shape
}

with open("dataset_info.json", "w") as outfile:
    json.dump(dictionary, outfile)

# %%
# Zipping into a dataset to be used

import zipfile

list_files = [training_dataset_npz, testing_dataset_npz, validation_dataset_npz, representative_dataset_npz, "/content/dataset_info.json"]

with zipfile.ZipFile('/content/drive/MyDrive/sheila_normalized_dataset.zip', 'w') as zipF:
    for file in list_files:
        zipF.write(file, compress_type=zipfile.ZIP_DEFLATED)

from google.colab import files
#files.download("/content/drive/MyDrive/sheila_normalized_dataset.zip")
