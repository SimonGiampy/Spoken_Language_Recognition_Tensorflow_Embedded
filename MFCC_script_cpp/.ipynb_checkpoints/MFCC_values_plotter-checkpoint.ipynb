# %%
import pandas as pd
import csv
import numpy as np
import matplotlib.pyplot as plt

# %%
def read_and_print_matrix_csv(file_path):
    matrix = []
    
    with open(file_path, 'r') as csv_file:
        csv_reader = csv.reader(csv_file)
        for row in csv_reader:
            matrix.append(row)
    
    for row in matrix:
        print(" ".join(row))

# %%
#MFCC COEFFICIENT WITHOUT ANY TRANSFORMATION (FLOAT VALUES)

file_path_1 = 'MFCC_float_coefficient.csv'
read_and_print_matrix_csv(file_path_1)
# Out:
# 59.0235 -1.80305 -0.119128 -0.492445 -1.73838 -1.81649 -0.639878 0.911303 -0.284477 -0.110102 -0.207777 -0.705001
# 58.3161 -1.56233 1.08151 0.266203 -2.04593 -2.43762 -0.631458 1.03435 0.00242007 -0.654553 -0.374979 -0.397509
# 59.0475 -2.50126 0.354344 -0.0764248 -1.68493 -1.87528 -0.31373 1.42504 0.128087 -0.309293 0.411406 0.189986
# 61.367 -3.42022 0.394458 -0.164637 -1.08414 -1.42746 -0.576155 1.34172 0.125142 0.358666 1.164 0.197086
# 64.0395 -3.68743 0.824868 0.8535 -0.890574 -1.40442 -0.0797899 0.902715 -0.180459 0.733405 1.05504 0.396379
# 69.4265 -5.03914 1.14425 1.25847 -0.264302 -0.725564 0.684671 0.618809 -0.95564 0.591099 1.15913 0.860804
# 78.0543 -3.14981 -1.14474 0.516055 -0.764087 -1.14431 -0.131417 0.610721 -0.7865 -0.252421 0.431489 -0.225334
# 84.0562 -2.81619 -3.39272 1.05942 -2.46179 -0.68417 -1.1828 1.10849 -1.3968 -0.217937 0.500375 -1.19719
# 87.0698 -4.0806 -4.07065 0.649282 -2.80595 -0.298044 -1.05896 1.3238 -1.73645 -0.167575 0.300262 -1.2719
# ...

# %%
#MFCC COEFFICIENT WITHOUT ANY TRANSFORMATION (FLOAT VALUES)

df = pd.read_csv(file_path_1, header=None)

# Extract MFCC values as a NumPy array
mfcc_values = df.values

plt.figure(figsize=(10, 6))
plt.imshow(mfcc_values, cmap='viridis', aspect='auto', interpolation = "none")

# Add labels and title
plt.xlabel('MFCC Coeffs')
plt.ylabel('Frames')
plt.title('MFCC Heatmap')

# Show colorbar
plt.colorbar(label='MFCC Values')
plt.show()

# %%
#MFCC COEFFICIENT NORMALIZED WITH ZSCORE TECHNIQUE (SUBTRACTING THE MEAN AND DIVIDING FOR THE VARIANCE)

file_path_2 = 'MFCC_float_normalized_coefficient.csv'
read_and_print_matrix_csv(file_path_2)
# Out:
# -0.0477781 0.181102 -0.173482 -0.251842 -0.756818 -1.39983 0.0780239 0.455578 -0.041201 0.030684 -0.745462 -0.230185
# -0.0508192 0.214043 0.133439 0.103087 -0.994029 -2.08623 0.0850843 0.501081 0.0516419 -0.998879 -0.910218 -0.0835005
# -0.0476747 0.0855539 -0.0524473 -0.0572096 -0.715587 -1.4648 0.351527 0.645561 0.0923091 -0.345988 -0.13534 0.196757
# -0.0377024 -0.0402021 -0.0421929 -0.098479 -0.252199 -0.96992 0.131461 0.614748 0.091356 0.917131 0.606242 0.200144
# -0.0262122 -0.0767687 0.0678337 0.37785 -0.1029 -0.944465 0.547706 0.452402 -0.0075397 1.62577 0.498878 0.295215
# -0.00305128 -0.261745 0.149479 0.567313 0.380147 -0.194266 1.18877 0.347412 -0.258396 1.35666 0.601446 0.516763
# 0.034043 -0.00319745 -0.435662 0.219978 -0.00533939 -0.657016 0.504412 0.344421 -0.203661 -0.238442 -0.115551 -0.00136613
# 0.0598473 0.0424561 -1.01032 0.474189 -1.31479 -0.148523 -0.37726 0.528498 -0.40116 -0.173233 -0.0476726 -0.464981
# ...

# %%
#MFCC COEFFICIENT NORMALIZED WITH ZSCORE TECHNIQUE (SUBTRACTING THE MEAN AND DIVIDING FOR THE VARIANCE)

df = pd.read_csv(file_path_2, header=None)
plt.figure(figsize=(10, 6))
plt.imshow(mfcc_values, cmap='viridis', aspect='auto', interpolation = "none")

# Add labels and title
plt.xlabel('MFCC Coeffs')
plt.ylabel('Frames')
plt.title('MFCC Heatmap')

# Show colorbar
plt.colorbar(label='MFCC Values')


# Show the plot
plt.show()

# %%
#MFCC COEFFICIENT QUANTIZED USING MIN MAX TECHNIQUE

file_path_3 = 'MFCC_quantized_coefficient.csv'
read_and_print_matrix_csv(file_path_3)
# Out:
# 46 -107 -103 -104 -107 -107 -104 -100 -103 -103 -103 -104
# 44 -106 -100 -102 -107 -108 -104 -100 -102 -104 -103 -103
# 46 -109 -101 -102 -107 -107 -103 -99 -102 -103 -101 -102
# 51 -111 -101 -103 -105 -106 -104 -99 -102 -101 -99 -102
# 58 -112 -100 -100 -105 -106 -102 -100 -103 -100 -100 -101
# 72 -115 -99 -99 -103 -104 -101 -101 -105 -101 -99 -100
# 93 -110 -105 -101 -104 -105 -103 -101 -104 -103 -101 -103
# 108 -109 -111 -100 -108 -104 -105 -100 -106 -103 -101 -105
# 116 -113 -112 -101 -109 -103 -105 -99 -107 -103 -102 -105
# 116 -115 -113 -102 -109 -103 -103 -100 -107 -103 -102 -106
# 114 -115 -112 -102 -109 -103 -102 -101 -107 -103 -103 -105
# 110 -116 -113 -102 -111 -104 -103 -103 -107 -104 -103 -106
# 110 -114 -111 -101 -111 -102 -102 -103 -106 -103 -102 -106
# 108 -114 -109 -101 -111 -102 -101 -103 -105 -103 -103 -106
# 107 -116 -107 -102 -111 -102 -102 -103 -105 -103 -104 -106
# 105 -116 -106 -101 -109 -101 -101 -104 -105 -103 -103 -106
# ...

# %%
#MFCC COEFFICIENT QUANTIZED USING MIN MAX TECHNIQUE

df = pd.read_csv(file_path_3, header=None)
plt.figure(figsize=(10, 6))
plt.imshow(mfcc_values, cmap='viridis', aspect='auto', interpolation = "none")

# Add labels and title
plt.xlabel('MFCC Coeffs')
plt.ylabel('Frames')
plt.title('MFCC Heatmap')

# Show colorbar
plt.colorbar(label='MFCC Values')

# Show the plot
plt.show()

# %%
#MFCC COEFFICIENT NORMALIZED AND QUANTIZED 

file_path_4 = 'MFCC_normalized_quantized_coefficient.csv'
read_and_print_matrix_csv(file_path_4)
# Out:
# 23 30 19 17 1 -19 27 39 23 26 1 17
# 23 32 29 28 -7 -41 27 41 26 -7 -4 22
# 23 27 23 23 2 -22 36 45 28 14 20 31
# 24 23 23 22 17 -6 29 44 28 54 44 31
# 24 22 27 37 21 -5 42 39 25 76 41 34
# 25 16 29 43 37 19 62 36 17 68 44 41
# 26 25 11 32 25 4 41 36 18 17 21 25
# 27 26 -7 40 -17 20 13 41 12 19 23 10
# 27 21 -13 34 -25 34 16 44 9 22 17 9
# 27 17 -14 27 -20 30 31 41 6 13 10 8
# 27 16 -12 27 -23 30 46 32 6 8 2 9
# 27 15 -13 26 -37 22 37 25 7 -1 -1 6
# 27 18 -8 30 -38 44 51 24 12 9 7 4
# 27 18 -1 29 -41 43 53 23 15 20 4 3
# 27 15 4 27 -40 41 49 23 14 20 -10 5
# 26 15 7 32 -25 59 57 22 13 23 1 6
# 26 16 5 36 -18 38 59 19 12 7 10 3
# 26 19 3 33 -1 6 46 19 14 -7 20 0
# 26 28 0 30 25 0 32 22 20 -24 19 3
# 25 36 6 43 52 -15 -2 18 24 -54 -7 19
# 25 36 11 53 40 -14 -6 21 28 -55 -1 20
# 25 34 15 60 29 -12 -6 23 24 -49 -1 18
# 25 31 15 59 32 -12 5 22 22 -69 4 21
# 25 30 15 60 40 -11 13 20 27 -57 4 20
# 25 30 12 58 37 -16 22 18 30 -54 2 15
# 25 30 13 61 46 -14 25 17 32 -43 1 12
# ...

# %%
#MFCC COEFFICIENT NORMALIZED AND QUANTIZED 

df = pd.read_csv(file_path_4, header=None)
plt.figure(figsize=(10, 6))
plt.imshow(mfcc_values, cmap='viridis', aspect='auto', interpolation = "none")

# Add labels and title
plt.xlabel('MFCC Coeffs')
plt.ylabel('Frames')
plt.title('MFCC Heatmap')

# Show colorbar
plt.colorbar(label='MFCC Values')

# Show the plot
plt.show()
